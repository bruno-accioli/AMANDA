# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.loadUG_2C_2D(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 11, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 11, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 11, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 11, 0.85, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 11)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, 'UG_2C_2D', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:72: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Two Bidimensional Unimodal Gaussian Classes.
# 100 batches of 950 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  4.0424093
# Average MCC:  -0.11529346356142035
# Average error: 55.9713
# Average macro-F1: 0.44094114380269095
# Average micro-F1: 0.44300000000000006
# Average Accuracy:  44.0287
# Standard Deviation:  34.95600451009812
# Variance:  1221.92225131
# METHOD: Sliding lp as classifier
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Execution time:  2.2727484000000002
# Average MCC:  0.36557945434341366
# Average error: 33.7585
# Average macro-F1: 0.5773851048919674
# Average micro-F1: 0.6653999999999999
# Average Accuracy:  66.2415
# Standard Deviation:  17.54574001716656
# Variance:  307.85299274999994
# METHOD: Incremental lp as classifier
# Execution time:  69.7793343
# Average MCC:  -0.09961404433860307
# Average error: 55.2068
# Average macro-F1: 0.4486961957485564
# Average micro-F1: 0.45080000000000003
# Average Accuracy:  44.7932
# Standard Deviation:  33.69545360668112
# Variance:  1135.3835937599997
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  9.768511400000008
# Average MCC:  0.5319087502428903
# Average error: 23.4739
# Average macro-F1: 0.7628048409293318
# Average micro-F1: 0.7646000000000001
# Average Accuracy:  76.5261
# Standard Deviation:  31.58180545488177
# Variance:  997.41043579
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=1 : Hellinger1 Invalid distance value(s): [1.4566569204346196, 1.6154849800462494]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=1 : Hellinger1 Invalid calculated alpha value: -0.12185738786733924
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=3 : Hellinger1 Invalid distance value(s): [2.2595044220281437, 1.6665062763984673]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=3 : Hellinger1 Invalid calculated alpha value: -0.5487917868402103
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=5 : Hellinger1 Invalid distance value(s): [2.1574953462797914, 1.6149925848321836]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=5 : Hellinger1 Invalid calculated alpha value: -0.47203040318289236
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=6 : Hellinger1 Invalid calculated alpha value: 1.2241453898442174
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=7 : Hellinger1 Invalid distance value(s): [2.471766834383946, 2.0258862993532527]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=7 : Hellinger1 Invalid calculated alpha value: -0.8346130044955042
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=9 : Hellinger1 Invalid distance value(s): [2.78782554765459, 1.847850823653456]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: -0.9036246232809277
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=10 : Hellinger1 Invalid calculated alpha value: 1.2525228867066742
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=11 : Hellinger1 Invalid distance value(s): [3.2853901940167978, 1.842269741125382]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=11 : Hellinger1 Invalid calculated alpha value: -1.149616405197995
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=13 : Hellinger1 Invalid distance value(s): [2.825157733407685, 1.9244749178876062]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=13 : Hellinger1 Invalid calculated alpha value: -0.9606027632745506
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=15 : Hellinger1 Invalid distance value(s): [2.602748834508964, 1.6461726831366754]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=15 : Hellinger1 Invalid calculated alpha value: -0.7102471964497246
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=17 : Hellinger1 Invalid distance value(s): [2.5111488917227045, 1.9189624102157963]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=80 : Hellinger1 Invalid distance value(s): [1.3335672954758047, 1.9801818106562148]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=80 : Hellinger1 Invalid calculated alpha value: -0.24266099069291447
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=81 : Hellinger1 Invalid calculated alpha value: 1.2826211574652557
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=82 : Hellinger1 Invalid distance value(s): [1.2903071590141264, 1.7441549372519272]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=82 : Hellinger1 Invalid calculated alpha value: -0.10301748575993153
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=84 : Hellinger1 Invalid distance value(s): [1.9122544374451171, 2.519049246808263]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=84 : Hellinger1 Invalid calculated alpha value: -0.8014382797535948
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=85 : Hellinger1 Invalid calculated alpha value: 1.2723014335408527
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=86 : Hellinger1 Invalid distance value(s): [1.5558440379076182, 2.519684600730377]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=86 : Hellinger1 Invalid calculated alpha value: -0.6235507569459025
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=87 : Hellinger1 Invalid calculated alpha value: 1.1397701122814548
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=88 : Hellinger1 Invalid distance value(s): [1.8003277503652286, 2.26578410443843]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=88 : Hellinger1 Invalid calculated alpha value: -0.618842365028734
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=90 : Hellinger1 Invalid distance value(s): [1.7104833242767725, 2.856124274385403]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=90 : Hellinger1 Invalid calculated alpha value: -0.8690902369579925
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=91 : Hellinger1 Invalid calculated alpha value: 1.141213047816091
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=92 : Hellinger1 Invalid distance value(s): [2.1269712947652994, 2.995918230921966]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=92 : Hellinger1 Invalid calculated alpha value: -1.1472312004705374
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=93 : Hellinger1 Invalid calculated alpha value: 1.0135812572794634
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=94 : Hellinger1 Invalid distance value(s): [1.971059919037416, 2.241441889535776]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=94 : Hellinger1 Invalid calculated alpha value: -0.6920373419135009
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=96 : Hellinger1 Invalid distance value(s): [2.30378687553099, 2.415675698873148]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=96 : Hellinger1 Invalid calculated alpha value: -0.9455177248289741
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=98 : Hellinger1 Invalid distance value(s): [1.716454084309906, 2.689606499609474]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=98 : Hellinger1 Invalid calculated alpha value: -0.7888167295865951
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=99 : Hellinger1 Invalid calculated alpha value: 1.121895883532093
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.32 | Std keeping percentage=0.19
# Execution time:  11.958300999999992
# Average MCC:  0.3721062728067173
# Average error: 31.44579999999999
# Average macro-F1: 0.6836838034268774
# Average micro-F1: 0.6854000000000002
# Average Accuracy:  68.55420000000001
# Standard Deviation:  40.0025289745536
# Variance:  1600.2023243600001
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.21 | Std keeping percentage=0.05
# Execution time:  10.5644602
# Average MCC:  0.511700220224415
# Average error: 24.78389999999999
# Average macro-F1: 0.7541112253848712
# Average micro-F1: 0.7548000000000001
# Average Accuracy:  75.21610000000001
# Standard Deviation:  33.381158275140784
# Variance:  1114.30172779
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.04
# Execution time:  10.7247366
# Average MCC:  0.3504028070013203
# Average error: 32.4237
# Average macro-F1: 0.6742445882397504
# Average micro-F1: 0.6753
# Average Accuracy:  67.5763
# Standard Deviation:  41.07478717303353
# Variance:  1687.1381413099996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.20 | Std keeping percentage=0.08
# Execution time:  11.5319772
# Average MCC:  0.35444640073215417
# Average error: 32.339
# Average macro-F1: 0.6761561469936054
# Average micro-F1: 0.6773
# Average Accuracy:  67.661
# Standard Deviation:  41.122583321090126
# Variance:  1691.0668589999998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.25 | Std keeping percentage=0.14
# Execution time:  10.751838399999997
# Average MCC:  0.35112327620658484
# Average error: 32.502700000000004
# Average macro-F1: 0.6734731027699635
# Average micro-F1: 0.6748999999999999
# Average Accuracy:  67.4973
# Standard Deviation:  41.37968590637198
# Variance:  1712.27840571
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.34 | Std keeping percentage=0.16
# Execution time:  10.945414
# Average MCC:  0.36541916068819086
# Average error: 31.822400000000002
# Average macro-F1: 0.6816391024584908
# Average micro-F1: 0.6823999999999999
# Average Accuracy:  68.1776
# Standard Deviation:  40.512638080480514
# Variance:  1641.2738442399998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  9.333624100000009
# Average MCC:  0.3473588829754377
# Average error: 32.63279999999999
# Average macro-F1: 0.6723953531316391
# Average micro-F1: 0.6736000000000001
# Average Accuracy:  67.36720000000001
# Standard Deviation:  40.99464338373978
# Variance:  1680.5607861599995
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.14 | Std keeping percentage=0.03
# Execution time:  10.165038699999997
# Average MCC:  0.39074947128527887
# Average error: 30.340099999999993
# Average macro-F1: 0.6931146654743757
# Average micro-F1: 0.6947
# Average Accuracy:  69.65990000000001
# Standard Deviation:  39.70369120107097
# Variance:  1576.38309499
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.15 | Std keeping percentage=0.03
# Execution time:  10.085882700000013
# Average MCC:  0.40594768717548113
# Average error: 29.533599999999993
# Average macro-F1: 0.700798743448938
# Average micro-F1: 0.7033000000000001
# Average Accuracy:  70.46640000000001
# Standard Deviation:  38.45250047838241
# Variance:  1478.5947930399996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.04
# Execution time:  9.390934299999998
# Average MCC:  0.8354223944832477
# Average error: 8.380099999999999
# Average macro-F1: 0.9136283869496257
# Average micro-F1: 0.915
# Average Accuracy:  91.6199
# Standard Deviation:  8.010240757305613
# Variance:  64.16395699
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: 50.450728729215264
# Error reduction: 1.7363674148907375
# Error reduction: 73.80958329453287
# Error reduction: 55.70343889326737
# Error reduction: 70.83425129517794
# Error reduction: 53.48238762443589
# Error reduction: 53.67476214378348
# Error reduction: 53.302959206154156
# Error reduction: 54.84808772459782
# Error reduction: 53.007470127439625
# Error reduction: 58.214755375471015
# Error reduction: 60.046515114005196
# Error reduction: 108.09131316618479
