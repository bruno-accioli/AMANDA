# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.loadMG_2C_2D(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 11, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 11, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 11, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 11, 0.7, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 11)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, 'MG_2C_2D', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:111: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Two Bidimensional Multimodal Gaussian Classes.
# 100 batches of 1900 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  7.0290174
# Average MCC:  -0.027125854043888387
# Average error: 51.3296
# Average macro-F1: 0.4805514709733827
# Average micro-F1: 0.48830000000000007
# Average Accuracy:  48.6704
# Standard Deviation:  35.44370087674254
# Variance:  1256.25593184
# METHOD: Sliding lp as classifier
# Execution time:  7.4954719999999995
# Average MCC:  0.10228698325040658
# Average error: 45.096000000000004
# Average macro-F1: 0.542874559023858
# Average micro-F1: 0.5474999999999999
# Average Accuracy:  54.903999999999996
# Standard Deviation:  34.51706493895447
# Variance:  1191.427772
# METHOD: Incremental lp as classifier
# Execution time:  214.9791711
# Average MCC:  -0.01885347348814971
# Average error: 51.4274
# Average macro-F1: 0.48564437275840716
# Average micro-F1: 0.48989999999999995
# Average Accuracy:  48.5726
# Standard Deviation:  37.00671705569139
# Variance:  1369.4971072399999
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  45.52425240000002
# Average MCC:  0.07185123488400186
# Average error: 46.32499999999999
# Average macro-F1: 0.5327961152588386
# Average micro-F1: 0.5368999999999999
# Average Accuracy:  53.67500000000001
# Standard Deviation:  33.83135789471064
# Variance:  1144.5607770000001
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=0 : Hellinger1 Invalid distance value(s): [1.1719224615008557]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=1 : Hellinger1 Invalid calculated alpha value: 1.1383290871391765
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=2 : Hellinger1 Invalid distance value(s): [1.6867321947328016, 1.881963709422029]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=2 : Hellinger1 Invalid calculated alpha value: -0.3701343897043201
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=3 : Hellinger1 Invalid calculated alpha value: 1.1413948921601351
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=4 : Hellinger1 Invalid distance value(s): [1.8766552512122328, 1.9366628523293288]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=4 : Hellinger1 Invalid calculated alpha value: -0.49244548939768573
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=5 : Hellinger1 Invalid calculated alpha value: 1.3697261560665235
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=6 : Hellinger1 Invalid distance value(s): [1.9792646634542403, 1.8708754361052338]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=6 : Hellinger1 Invalid calculated alpha value: -0.5108564874066419
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=7 : Hellinger1 Invalid calculated alpha value: 1.1025989794576125
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=8 : Hellinger1 Invalid distance value(s): [2.1401111305169356, 1.925847167082773]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=8 : Hellinger1 Invalid calculated alpha value: -0.6187655864267592
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: 1.246454259009495
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=10 : Hellinger1 Invalid distance value(s): [2.5089551455451207, 2.362801450015328]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=10 : Hellinger1 Invalid calculated alpha value: -1.021664735407129
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=11 : Hellinger1 Invalid calculated alpha value: 1.0671866300867765
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=12 : Hellinger1 Invalid distance value(s): [1.9412288508088487, 2.10264034353347]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=12 : Hellinger1 Invalid calculated alpha value: -0.6077210347980644
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=13 : Hellinger1 Invalid calculated alpha value: 1.249470695083427
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=14 : Hellinger1 Invalid distance value(s): [2.1954719827200213, 1.8111885335475582]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=14 : Hellinger1 Invalid calculated alpha value: -0.5891166957606948
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=16 : Hellinger1 Invalid distance value(s): [2.0165267079112295, 1.9668822475012187]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=16 : Hellinger1 Invalid calculated alpha value: -0.5774909153331289
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=82 : Hellinger1 Invalid distance value(s): [1.931662642212506, 1.8618549737473413]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=82 : Hellinger1 Invalid calculated alpha value: -0.48254524560682843
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=84 : Hellinger1 Invalid distance value(s): [1.912746096078777, 2.224592568688943]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=84 : Hellinger1 Invalid calculated alpha value: -0.6544557700107647
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=86 : Hellinger1 Invalid distance value(s): [2.363874286684476, 2.1180266376955705]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=86 : Hellinger1 Invalid calculated alpha value: -0.8267368998169282
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=87 : Hellinger1 Invalid calculated alpha value: 1.2179201806575375
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=88 : Hellinger1 Invalid distance value(s): [4.203875927710575, 2.0952883097308304]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=88 : Hellinger1 Invalid calculated alpha value: -1.7353685563476076
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=89 : Hellinger1 Invalid calculated alpha value: 1.1210000029527918
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=90 : Hellinger1 Invalid distance value(s): [4.189981897188419, 2.671883517910613]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=90 : Hellinger1 Invalid calculated alpha value: -2.0167191451764213
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=91 : Hellinger1 Invalid calculated alpha value: 1.1619256554562098
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=92 : Hellinger1 Invalid distance value(s): [4.441077974037194, 4.238976633292291]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=92 : Hellinger1 Invalid calculated alpha value: -2.9258137412916474
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=93 : Hellinger1 Invalid distance value(s): [1.1822883770408135]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=94 : Hellinger1 Invalid calculated alpha value: 1.196830194327541
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [4.333327690357324, 4.690107014116283]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=95 : Hellinger1 Invalid calculated alpha value: -3.0975037898637083
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=96 : Hellinger1 Invalid calculated alpha value: 1.093180837081157
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=97 : Hellinger1 Invalid distance value(s): [4.772666302429614, 4.461052267183738]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=97 : Hellinger1 Invalid calculated alpha value: -3.202645722433581
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=98 : Hellinger1 Invalid calculated alpha value: 1.0025470958406635
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=99 : Hellinger1 Invalid distance value(s): [5.235761605181554, 4.708202966639831]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=99 : Hellinger1 Invalid calculated alpha value: -3.557768723537598
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.32 | Std keeping percentage=0.19
# Execution time:  47.2365901
# Average MCC:  0.27541580398509247
# Average error: 35.95389999999999
# Average macro-F1: 0.6301785446114971
# Average micro-F1: 0.6391
# Average Accuracy:  64.04610000000001
# Standard Deviation:  25.98507097912184
# Variance:  675.2239137900001
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.22 | Std keeping percentage=0.05
# Execution time:  42.33525989999998
# Average MCC:  0.0778621314958397
# Average error: 46.421699999999994
# Average macro-F1: 0.5324380926911281
# Average micro-F1: 0.5407
# Average Accuracy:  53.578300000000006
# Standard Deviation:  36.203672356682276
# Variance:  1310.7058921100004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.08
# Execution time:  42.609063400000025
# Average MCC:  0.2826855658326287
# Average error: 35.9221
# Average macro-F1: 0.635286527877234
# Average micro-F1: 0.6441000000000001
# Average Accuracy:  64.0779
# Standard Deviation:  25.345007922468675
# Variance:  642.3694265899999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.21 | Std keeping percentage=0.10
# Execution time:  41.09862129999999
# Average MCC:  0.018239897884576643
# Average error: 49.323499999999996
# Average macro-F1: 0.504461664075683
# Average micro-F1: 0.5118
# Average Accuracy:  50.676500000000004
# Standard Deviation:  37.90254649426605
# Variance:  1436.6030307499996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.25 | Std keeping percentage=0.15
# Execution time:  44.195653100000015
# Average MCC:  0.010775328482790263
# Average error: 49.28889999999999
# Average macro-F1: 0.5005571091664821
# Average micro-F1: 0.5093
# Average Accuracy:  50.71110000000001
# Standard Deviation:  37.80081652279485
# Variance:  1428.90172979
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.32 | Std keeping percentage=0.18
# Execution time:  43.0331276
# Average MCC:  0.014623774454192481
# Average error: 49.70909999999999
# Average macro-F1: 0.5029503923370543
# Average micro-F1: 0.5094
# Average Accuracy:  50.29090000000001
# Standard Deviation:  38.676863422335586
# Variance:  1495.8997641900003
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  37.31382339999993
# Average MCC:  0.30171834503085554
# Average error: 34.90939999999999
# Average macro-F1: 0.64121102957641
# Average micro-F1: 0.6494000000000001
# Average Accuracy:  65.09060000000001
# Standard Deviation:  23.723683053859915
# Variance:  562.8131376400001
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.14 | Std keeping percentage=0.04
# Execution time:  35.42131979999999
# Average MCC:  0.2887583382367885
# Average error: 35.31259999999999
# Average macro-F1: 0.6367827569279583
# Average micro-F1: 0.6451
# Average Accuracy:  64.68740000000001
# Standard Deviation:  24.0765950507957
# Variance:  579.6824292399999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.16 | Std keeping percentage=0.04
# Execution time:  39.04251290000002
# Average MCC:  0.007239188715687823
# Average error: 49.7925
# Average macro-F1: 0.4977366553907915
# Average micro-F1: 0.5061
# Average Accuracy:  50.2075
# Standard Deviation:  37.72128431999632
# Variance:  1422.8952907500004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.07
# Execution time:  27.61507990000007
# Average MCC:  0.27082867170248753
# Average error: 36.5668
# Average macro-F1: 0.6290075764263338
# Average micro-F1: 0.6385000000000001
# Average Accuracy:  63.4332
# Standard Deviation:  25.24907791900528
# Variance:  637.51593576
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: 12.807784608304013
# Error reduction: -0.20094348926657565
# Error reduction: 10.282635852592152
# Error reduction: 31.591480653538923
# Error reduction: 10.083952463920586
# Error reduction: 31.65681810710411
# Error reduction: 4.121807094250311
# Error reduction: 4.192897531148312
# Error reduction: 3.329539103849582
# Error reduction: 33.73754890035834
# Error reduction: 32.90911930043725
# Error reduction: 3.1581823860087495
# Error reduction: 30.332193694730265
