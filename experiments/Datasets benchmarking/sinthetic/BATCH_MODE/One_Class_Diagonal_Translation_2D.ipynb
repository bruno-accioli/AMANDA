# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
import numpy as np
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version
#from methods import lstm


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ np.asarray(predictions[i::steps]) for i in range(steps) ]
    
    #print("predictions",np.shape(predictions))
    #print("originalAccs",key,originalAccs[key])
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, nb = naive bayes, knn = k-nn, sgd = stochastic gradient descent
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.loadCDT(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))
    #'''
    # Static SSL
    experiments[0] = Experiment(static_classifier, 2, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 2, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 2, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 2, 0.85, "kde", clfName=sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 2)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '1CDT', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    #'''
    # Upper-bound
    #experiments[6] = Experiment(lstm, 2)
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:20: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# One Class Diagonal Translation. 2 Dimensional data.
# 100 batches of 152 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  0.4595052
# Average MCC:  0.979228085282648
# Average error: 1.106499999999997
# Average macro-F1: 0.9894121399668632
# Average micro-F1: 0.9895
# Average Accuracy:  98.8935
# Standard Deviation:  0.8565259774227493
# Variance:  0.733636749999996
# METHOD: Sliding lp as classifier
# Execution time:  0.4238799
# Average MCC:  0.9990034762249309
# Average error: 0.07259999999998001
# Average macro-F1: 0.9994967231128838
# Average micro-F1: 0.9994999999999998
# Average Accuracy:  99.92740000000002
# Standard Deviation:  0.2450902690846794
# Variance:  0.06006924000000056
# METHOD: Incremental lp as classifier
# Execution time:  5.0297725
# Average MCC:  0.9823581364739821
# Average error: 0.8437000000000126
# Average macro-F1: 0.9910265022205319
# Average micro-F1: 0.9911
# Average Accuracy:  99.15629999999999
# Standard Deviation:  0.7093019878725818
# Variance:  0.5031093099999961
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  2.370168399999999
# Average MCC:  0.9994039922956202
# Average error: 0.026399999999995316
# Average macro-F1: 0.9996990063340444
# Average micro-F1: 0.9997
# Average Accuracy:  99.9736
# Standard Deviation:  0.12933305841895393
# Variance:  0.01672704000000055
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=1 : Hellinger1 Invalid distance value(s): [1.4635387295059947]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=3 : Hellinger1 Invalid distance value(s): [1.2988202277855894, 1.2240162739109088]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=4 : Hellinger1 Invalid calculated alpha value: 1.0430515584249447
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=5 : Hellinger1 Invalid distance value(s): [1.0599008984209228, 1.0308458425413822]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=6 : Hellinger1 Invalid calculated alpha value: 1.1815702134354913
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=7 : Hellinger1 Invalid distance value(s): [1.101853449850063]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=8 : Hellinger1 Invalid calculated alpha value: 1.1678488046816777
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=9 : Hellinger1 Invalid distance value(s): [1.1476923245735144]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=10 : Hellinger1 Invalid calculated alpha value: 1.1800015065102112
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=11 : Hellinger1 Invalid distance value(s): [1.2307773967308686]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=12 : Hellinger1 Invalid calculated alpha value: 1.1489526753138748
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=18 : Hellinger1 Invalid distance value(s): [1.0198666309910493, 1.1335083933544665]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=27 : Hellinger1 Invalid calculated alpha value: 1.2110785801357666
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=30 : Hellinger1 Invalid calculated alpha value: 1.0733664242362515
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=37 : Hellinger1 Invalid distance value(s): [1.1253434638057256]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=38 : Hellinger1 Invalid calculated alpha value: 1.337499832329172
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=40 : Hellinger1 Invalid calculated alpha value: 1.3028607274091775
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=50 : Hellinger1 Invalid calculated alpha value: 1.1227200966493696
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=60 : Hellinger1 Invalid calculated alpha value: 1.021079015623257
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=63 : Hellinger1 Invalid calculated alpha value: 1.062026710140458
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=65 : Hellinger1 Invalid calculated alpha value: 1.0248474719976566
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=73 : Hellinger1 Invalid calculated alpha value: 1.2225274152240586
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=79 : Hellinger1 Invalid calculated alpha value: 1.0059158863064779
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=82 : Hellinger1 Invalid calculated alpha value: 1.028412551687237
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=84 : Hellinger1 Invalid calculated alpha value: 1.1986791743580563
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=86 : Hellinger1 Invalid calculated alpha value: 1.3721101152935558
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=89 : Hellinger1 Invalid calculated alpha value: 1.142660740216102
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=91 : Hellinger1 Invalid distance value(s): [1.0764877900734457]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [1.0859126791255649]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=96 : Hellinger1 Invalid calculated alpha value: 1.3179928193719264
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=97 : Hellinger1 Invalid distance value(s): [1.0504636011206914, 1.1871142744760428]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=98 : Hellinger1 Invalid calculated alpha value: 1.3413677340526913
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=99 : Hellinger1 Invalid distance value(s): [1.036683517380194, 1.2900208943778846]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.25 | Std keeping percentage=0.15
# Execution time:  2.412381
# Average MCC:  0.9986143760360957
# Average error: 0.05930000000000746
# Average macro-F1: 0.9992962630804098
# Average micro-F1: 0.9993
# Average Accuracy:  99.94069999999999
# Standard Deviation:  0.26484053692741283
# Variance:  0.07014051000000032
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.23 | Std keeping percentage=0.06
# Execution time:  0.900653700000003
# Average MCC:  0.999208957103366
# Average error: 0.039500000000003865
# Average macro-F1: 0.999598534359246
# Average micro-F1: 0.9995999999999999
# Average Accuracy:  99.9605
# Standard Deviation:  0.2243139540911362
# Variance:  0.050316750000000354
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.06
# Execution time:  0.8716245000000029
# Average MCC:  0.9988100247578484
# Average error: 0.05270000000000152
# Average macro-F1: 0.9993970589123535
# Average micro-F1: 0.9994
# Average Accuracy:  99.9473
# Standard Deviation:  0.24044065795950692
# Variance:  0.0578117100000006
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.07
# Execution time:  0.9150995999999978
# Average MCC:  0.9988100247578484
# Average error: 0.05270000000000152
# Average macro-F1: 0.9993970589123535
# Average micro-F1: 0.9994
# Average Accuracy:  99.9473
# Standard Deviation:  0.24044065795950692
# Variance:  0.0578117100000006
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.23 | Std keeping percentage=0.09
# Execution time:  0.9580155000000019
# Average MCC:  0.999010445887726
# Average error: 0.0461000000000098
# Average macro-F1: 0.9994982837326795
# Average micro-F1: 0.9995
# Average Accuracy:  99.95389999999999
# Standard Deviation:  0.23261081230243894
# Variance:  0.054107790000000475
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.40 | Std keeping percentage=0.09
# Execution time:  2.117221699999998
# Average MCC:  0.9994074683190058
# Average error: 0.0461000000000098
# Average macro-F1: 0.9996987849858123
# Average micro-F1: 0.9997
# Average Accuracy:  99.95389999999999
# Standard Deviation:  0.23261081230243894
# Variance:  0.054107790000000475
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  1.3834619000000004
# Average MCC:  0.9986143760360957
# Average error: 0.05930000000000746
# Average macro-F1: 0.9992962630804098
# Average micro-F1: 0.9993
# Average Accuracy:  99.94069999999999
# Standard Deviation:  0.26484053692741283
# Variance:  0.07014051000000032
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.13 | Std keeping percentage=0.03
# Execution time:  1.2542671999999975
# Average MCC:  0.9988100247578484
# Average error: 0.05270000000000152
# Average macro-F1: 0.9993970589123535
# Average micro-F1: 0.9994
# Average Accuracy:  99.9473
# Standard Deviation:  0.24044065795950692
# Variance:  0.0578117100000006
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.15 | Std keeping percentage=0.04
# Execution time:  0.971143099999999
# Average MCC:  0.9988100247578484
# Average error: 0.05270000000000152
# Average macro-F1: 0.9993970589123535
# Average micro-F1: 0.9994
# Average Accuracy:  99.9473
# Standard Deviation:  0.24044065795950692
# Variance:  0.0578117100000006
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.17 | Std keeping percentage=0.05
# Execution time:  0.8988711000000009
# Average MCC:  0.9988100247578484
# Average error: 0.05270000000000152
# Average macro-F1: 0.9993970589123535
# Average micro-F1: 0.9994
# Average Accuracy:  99.9473
# Standard Deviation:  0.24044065795950692
# Variance:  0.0578117100000006
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: 1.0454681045771632
# Error reduction: 0.2657404177220792
# Error reduction: 1.0921850273273792
# Error reduction: 1.058916915671899
# Error reduction: 1.0789384539934304
# Error reduction: 1.065590761779081
# Error reduction: 1.065590761779081
# Error reduction: 1.0722646078862486
# Error reduction: 1.0722646078862486
# Error reduction: 1.058916915671899
# Error reduction: 1.065590761779081
# Error reduction: 1.065590761779081
# Error reduction: 1.065590761779081
