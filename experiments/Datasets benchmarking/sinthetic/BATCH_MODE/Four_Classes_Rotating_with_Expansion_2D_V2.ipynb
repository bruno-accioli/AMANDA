# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = False
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load4CRE_V2(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 9, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 9, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 9, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 9, 0.9, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 9)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '4CRE-V2', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:202: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Four Classes Rotating with Expansion V2. Bidimensional.
# 100 batches of 1738 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  5.5123503000000005
# Average error: 79.4969
# Average macro-F1: 0.2047643491935779
# Average micro-F1: 0.20659999999999998
# Average Accuracy:  20.5031
# Standard Deviation:  31.00365941933307
# Variance:  961.2268973900001
# METHOD: Sliding lp as classifier
# Execution time:  4.287742999999999
# Average error: 81.9503
# Average macro-F1: 0.1773876876332035
# Average micro-F1: 0.18340000000000004
# Average Accuracy:  18.049699999999998
# Standard Deviation:  26.006491168744777
# Variance:  676.33758291
# METHOD: Incremental lp as classifier
# Execution time:  162.98833739999998
# Average error: 79.6345
# Average macro-F1: 0.20472558946427985
# Average micro-F1: 0.2064
# Average Accuracy:  20.365499999999997
# Standard Deviation:  30.920038304471746
# Variance:  956.04876875
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  32.77104220000001
# Average error: 79.494
# Average macro-F1: 0.20640064001886105
# Average micro-F1: 0.2082
# Average Accuracy:  20.506
# Standard Deviation:  34.177026523675224
# Variance:  1168.0691419999998
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=0 : Hellinger1 Invalid distance value(s): [1.9708568785508012, 1.922018502055079]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=0 : Hellinger1 Invalid calculated alpha value: -0.532224127929845
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=1 : Hellinger1 Invalid calculated alpha value: 1.136855457935193
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=2 : Hellinger1 Invalid distance value(s): [2.090410154618097, 2.408789613070639]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=2 : Hellinger1 Invalid calculated alpha value: -0.8353863214712731
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=4 : Hellinger1 Invalid distance value(s): [1.481434233906541, 1.5349241733912995]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=4 : Hellinger1 Invalid calculated alpha value: -0.09396564127582496
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=5 : Hellinger1 Invalid calculated alpha value: 1.3308216197399096
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=6 : Hellinger1 Invalid distance value(s): [1.296741090439707, 1.434686370580305]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=8 : Hellinger1 Invalid distance value(s): [1.9758860615253284, 1.9046024643513333]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=8 : Hellinger1 Invalid calculated alpha value: -0.5260307005652358
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: 1.319311685407564
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=10 : Hellinger1 Invalid distance value(s): [1.805634079265798, 2.3105993394644853]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=10 : Hellinger1 Invalid calculated alpha value: -0.6439031469920466
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=12 : Hellinger1 Invalid distance value(s): [1.6456849076042388, 1.168909540478741]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=14 : Hellinger1 Invalid distance value(s): [1.6722062614668496, 1.2601534294604138]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=14 : Hellinger1 Invalid calculated alpha value: -0.051966283090536525
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=15 : Hellinger1 Invalid calculated alpha value: 1.2420772893208543
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=16 : Hellinger1 Invalid distance value(s): [1.2976635441798565, 1.2629349771815284]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=18 : Hellinger1 Invalid distance value(s): [2.3452448198577875, 1.9988882159769306]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=18 : Hellinger1 Invalid calculated alpha value: -0.7578529555442637
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=21 : Hellinger1 Invalid distance value(s): [2.1535870275821676, 2.5173235576735333]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=21 : Hellinger1 Invalid calculated alpha value: -0.9212417302547553
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=23 : Hellinger1 Invalid distance value(s): [2.045883935681563, 1.760474985249307]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=23 : Hellinger1 Invalid calculated alpha value: -0.4889658980923397
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=25 : Hellinger1 Invalid distance value(s): [1.366534193726214, 2.027042920629973]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=25 : Hellinger1 Invalid calculated alpha value: -0.2825749948049985
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=26 : Hellinger1 Invalid calculated alpha value: 1.065847025443546
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=27 : Hellinger1 Invalid distance value(s): [1.6233007823790735, 2.1874328911986365]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=27 : Hellinger1 Invalid calculated alpha value: -0.49115327441575984
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=28 : Hellinger1 Invalid calculated alpha value: 1.1681254425122176
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=29 : Hellinger1 Invalid distance value(s): [1.7776598843631093, 1.8441741845091906]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=29 : Hellinger1 Invalid calculated alpha value: -0.3967034720630547
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=30 : Hellinger1 Invalid calculated alpha value: 1.231726991703408
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=31 : Hellinger1 Invalid distance value(s): [1.0031645439856751, 1.3847330283237425]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=32 : Hellinger1 Invalid distance value(s): [1.292931033208597]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=33 : Hellinger1 Invalid calculated alpha value: 1.1655249129120422
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=34 : Hellinger1 Invalid distance value(s): [1.4662108219218113, 1.4935323618401457]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=34 : Hellinger1 Invalid calculated alpha value: -0.06565802950788346
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=35 : Hellinger1 Invalid calculated alpha value: 1.3773179494417105
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=36 : Hellinger1 Invalid distance value(s): [2.227161614377804, 2.3930007937355264]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=36 : Hellinger1 Invalid calculated alpha value: -0.89586764168357
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=37 : Hellinger1 Invalid calculated alpha value: 1.0269290776569608
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=38 : Hellinger1 Invalid distance value(s): [2.0114106602335204, 1.7047570776097507]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=38 : Hellinger1 Invalid calculated alpha value: -0.44387030654854054
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=40 : Hellinger1 Invalid distance value(s): [1.3626302020539423, 1.538887267550149]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=40 : Hellinger1 Invalid calculated alpha value: -0.0365451724289505
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=41 : Hellinger1 Invalid calculated alpha value: 1.150162396509519
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=42 : Hellinger1 Invalid distance value(s): [1.4286004574997664, 1.2646003425510342]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=43 : Hellinger1 Invalid calculated alpha value: 1.3341569113637508
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=44 : Hellinger1 Invalid distance value(s): [1.8502362843446822, 1.9298504291793956]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=44 : Hellinger1 Invalid calculated alpha value: -0.4758297943889438
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=46 : Hellinger1 Invalid distance value(s): [1.72255987588607, 1.4832348729798248]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=46 : Hellinger1 Invalid calculated alpha value: -0.18868381205985219
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=47 : Hellinger1 Invalid calculated alpha value: 1.3139531116283725
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=48 : Hellinger1 Invalid distance value(s): [1.283139857270016, 1.1757376299675628]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=49 : Hellinger1 Invalid calculated alpha value: 1.0830579226612858
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=50 : Hellinger1 Invalid distance value(s): [1.3287098358638088]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=52 : Hellinger1 Invalid distance value(s): [2.1734808153826477, 1.5787360799457653]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=52 : Hellinger1 Invalid calculated alpha value: -0.46189488529111133
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=54 : Hellinger1 Invalid distance value(s): [2.2689344784153533, 2.9382144889660267]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=54 : Hellinger1 Invalid calculated alpha value: -1.189360921317595
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=55 : Hellinger1 Invalid distance value(s): [1.1717723022118747]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=58 : Hellinger1 Invalid distance value(s): [1.852941892281897, 1.668512298418588]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=58 : Hellinger1 Invalid calculated alpha value: -0.3465135329771474
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=61 : Hellinger1 Invalid distance value(s): [1.0540315099478206, 1.5016156847314865]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=63 : Hellinger1 Invalid distance value(s): [1.5996764028266894, 1.3709859705587506]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=63 : Hellinger1 Invalid calculated alpha value: -0.07111762431962476
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=65 : Hellinger1 Invalid calculated alpha value: 1.204766435408897
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=66 : Hellinger1 Invalid distance value(s): [1.096331036595925]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=67 : Hellinger1 Invalid calculated alpha value: 1.232648770078236
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=68 : Hellinger1 Invalid distance value(s): [1.2836618203781016, 1.099543893936635]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=69 : Hellinger1 Invalid calculated alpha value: 1.236819461508595
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=70 : Hellinger1 Invalid distance value(s): [2.3176212211096887, 2.197991221604882]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=70 : Hellinger1 Invalid calculated alpha value: -0.8435926589841902
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=71 : Hellinger1 Invalid calculated alpha value: 1.1480120311235764
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=72 : Hellinger1 Invalid distance value(s): [1.9433678895397013, 2.6580022697287617]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=72 : Hellinger1 Invalid calculated alpha value: -0.8864715172611362
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=73 : Hellinger1 Invalid calculated alpha value: 1.0501057542963474
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=74 : Hellinger1 Invalid distance value(s): [1.7809500094612378, 2.0917949885339184]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=74 : Hellinger1 Invalid calculated alpha value: -0.522158936624483
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=75 : Hellinger1 Invalid calculated alpha value: 1.303489236122474
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=76 : Hellinger1 Invalid distance value(s): [1.3666642803571272, 1.6542712748288761]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=76 : Hellinger1 Invalid calculated alpha value: -0.09625421521990662
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=78 : Hellinger1 Invalid distance value(s): [1.5541301167722148, 2.474953031022157]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=78 : Hellinger1 Invalid calculated alpha value: -0.600328011524091
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=79 : Hellinger1 Invalid distance value(s): [1.2658016838786836]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=80 : Hellinger1 Invalid distance value(s): [1.0436760416792694]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=81 : Hellinger1 Invalid calculated alpha value: 1.2774941293484618
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=82 : Hellinger1 Invalid distance value(s): [1.6727133693729397, 1.7176528473134571]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=82 : Hellinger1 Invalid calculated alpha value: -0.2809695459701034
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=83 : Hellinger1 Invalid calculated alpha value: 1.0684896122981165
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=84 : Hellinger1 Invalid distance value(s): [1.398001558242453, 1.0878547465232684]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=85 : Hellinger1 Invalid calculated alpha value: 1.1279008750880548
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=86 : Hellinger1 Invalid distance value(s): [1.343733412817172, 1.5895475043343776]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=86 : Hellinger1 Invalid calculated alpha value: -0.05242689620267971
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=87 : Hellinger1 Invalid calculated alpha value: 1.0024800986818696
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=88 : Hellinger1 Invalid distance value(s): [2.3932840568544043, 2.2644537424023903]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=88 : Hellinger1 Invalid calculated alpha value: -0.9146553372553023
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=90 : Hellinger1 Invalid distance value(s): [2.6858680064646054, 2.7575632045963885]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=90 : Hellinger1 Invalid calculated alpha value: -1.3075020431574018
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=91 : Hellinger1 Invalid distance value(s): [1.2043423670227227]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=93 : Hellinger1 Invalid distance value(s): [1.5846780394007758, 1.7697004741638238]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=93 : Hellinger1 Invalid calculated alpha value: -0.26297569440920454
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=94 : Hellinger1 Invalid calculated alpha value: 1.1761812873108324
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [1.3884179196973494, 1.3170607013645244]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=96 : Hellinger1 Invalid calculated alpha value: 1.1724973032029744
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=97 : Hellinger1 Invalid distance value(s): [1.6424940811265918, 1.368332480293148]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=97 : Hellinger1 Invalid calculated alpha value: -0.09119971833677476
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=98 : Hellinger1 Invalid calculated alpha value: 1.1480903966988565
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=99 : Hellinger1 Invalid distance value(s): [1.133567847575747, 1.8353682862824807]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=99 : Hellinger1 Invalid calculated alpha value: -0.07025450455601878
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.31 | Std keeping percentage=0.19
# Execution time:  32.205306999999976
# Average error: 72.1526
# Average macro-F1: 0.27834011625370736
# Average micro-F1: 0.28009999999999996
# Average Accuracy:  27.847399999999997
# Standard Deviation:  36.60365524425122
# Variance:  1339.82757724
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.17 | Std keeping percentage=0.05
# Execution time:  29.201254500000005
# Average error: 73.9616
# Average macro-F1: 0.2544709701306743
# Average micro-F1: 0.2622
# Average Accuracy:  26.038399999999996
# Standard Deviation:  31.07943486358785
# Variance:  965.9312714399998
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.03
# Execution time:  29.838999799999954
# Average error: 79.50890000000001
# Average macro-F1: 0.20578986811834007
# Average micro-F1: 0.20779999999999998
# Average Accuracy:  20.491099999999996
# Standard Deviation:  34.10544982535782
# Variance:  1163.18170779
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.03
# Execution time:  28.367102199999977
# Average error: 90.1529
# Average macro-F1: 0.0955524901436662
# Average micro-F1: 0.10169999999999998
# Average Accuracy:  9.847100000000001
# Standard Deviation:  14.837081201840203
# Variance:  220.1389785899999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.14 | Std keeping percentage=0.05
# Execution time:  28.70945899999998
# Average error: 78.2086
# Average macro-F1: 0.20538323271898495
# Average micro-F1: 0.21410000000000004
# Average Accuracy:  21.7914
# Standard Deviation:  29.13356167789994
# Variance:  848.76441604
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.28 | Std keeping percentage=0.10
# Execution time:  29.435035099999993
# Average error: 82.6358
# Average macro-F1: 0.1650193707290835
# Average micro-F1: 0.182
# Average Accuracy:  17.364199999999997
# Standard Deviation:  22.519244133851384
# Variance:  507.11635635999994
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  28.62501689999999
# Average error: 79.494
# Average macro-F1: 0.20640064001886105
# Average micro-F1: 0.2082
# Average Accuracy:  20.506
# Standard Deviation:  34.177026523675224
# Variance:  1168.0691419999998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.10 | Std keeping percentage=0.01
# Execution time:  32.812608100000034
# Average error: 79.47890000000001
# Average macro-F1: 0.20637435570704238
# Average micro-F1: 0.2082
# Average Accuracy:  20.521099999999997
# Standard Deviation:  34.166407065859296
# Variance:  1167.34337179
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.01
# Execution time:  31.449822700000027
# Average error: 79.4419
# Average macro-F1: 0.20718602850577042
# Average micro-F1: 0.2091
# Average Accuracy:  20.558099999999996
# Standard Deviation:  34.1710714112098
# Variance:  1167.6621213899998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  29.86361790000001
# Average error: 79.39789999999999
# Average macro-F1: 0.20753161692221184
# Average micro-F1: 0.2095
# Average Accuracy:  20.6021
# Standard Deviation:  34.145243513409014
# Variance:  1165.8976545900002
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: -11.96599538606358
# Error reduction: -0.6711180260546094
# Error reduction: 0.014144202584001182
# Error reduction: 35.82043690954049
# Error reduction: 26.997380883866324
# Error reduction: -0.05852773483036228
# Error reduction: -51.972628529344334
# Error reduction: 6.283440065160876
# Error reduction: -15.309392238246913
# Error reduction: 0.014144202584001182
# Error reduction: 0.08779160224550009
# Error reduction: 0.26825211797238546
# Error reduction: 0.48285381235032854
