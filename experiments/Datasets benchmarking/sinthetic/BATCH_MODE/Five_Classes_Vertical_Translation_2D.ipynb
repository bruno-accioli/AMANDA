# %%
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = False
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load5CVT(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 8, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 8, clfName=sslClassifier)
    
    # Incremental SSL
    #experiments[2] = Experiment(incremental_LN, 8, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 8, 0.85, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.0001)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.001)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.001)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[14] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[15] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[16] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)


    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 8)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '5CVT', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\setup.py:163: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Five Classes Vertical Translation. Bidimensional.
# 100 batches of 228 instances
#
#
#
# METHOD: Static lp as classifier
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Execution time:  0.4886683380592004
# Average error: 55.5009
# Average macro-F1: 0.3472425299684842
# Average micro-F1: 0.4428999999999999
# Average Accuracy:  44.4991
# Standard Deviation:  19.10053706548588
# Variance:  364.83051618999997
# METHOD: Sliding lp as classifier
# Execution time:  0.4219920921424336
# Average error: 67.6977
# Average macro-F1: 0.21524739095057113
# Average micro-F1: 0.3234
# Average Accuracy:  32.302299999999995
# Standard Deviation:  9.801528437442807
# Variance:  96.06995971000002
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  0.8024447614720074
# Average error: 71.63999999999999
# Average macro-F1: 0.1998931864685713
# Average micro-F1: 0.2852
# Average Accuracy:  28.36000000000001
# Standard Deviation:  14.200706179623602
# Variance:  201.66005599999994
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=0 : Hellinger1 Invalid calculated alpha value: 1.0235649414745556
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=3 : Hellinger1 Invalid calculated alpha value: 1.134561889015556
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=4 : Hellinger1 Invalid calculated alpha value: 1.2584703711020788
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=5 : Hellinger1 Invalid distance value(s): [1.1468539997426637]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=6 : Hellinger1 Invalid calculated alpha value: 1.1469873186633557
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=8 : Hellinger1 Invalid calculated alpha value: 1.2568193712101086
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: 1.2128659993593607
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=10 : Hellinger1 Invalid calculated alpha value: 1.101127854033082
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=11 : Hellinger1 Invalid calculated alpha value: 1.3340047000184385
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=12 : Hellinger1 Invalid distance value(s): [1.1705316426876806]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=15 : Hellinger1 Invalid distance value(s): [1.207317232197313]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=16 : Hellinger1 Invalid calculated alpha value: 1.062102528952497
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=18 : Hellinger1 Invalid calculated alpha value: 1.123022603768296
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=19 : Hellinger1 Invalid calculated alpha value: 1.3369589756239055
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=20 : Hellinger1 Invalid calculated alpha value: 1.1274190265804105
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=21 : Hellinger1 Invalid calculated alpha value: 1.0874949998121415
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=22 : Hellinger1 Invalid distance value(s): [1.0373972390652546, 1.1629621079103543]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=23 : Hellinger1 Invalid calculated alpha value: 1.076454998503195
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=24 : Hellinger1 Invalid distance value(s): [1.4903327564804378]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=25 : Hellinger1 Invalid calculated alpha value: 1.139478023221914
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=27 : Hellinger1 Invalid calculated alpha value: 1.1316087078974568
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=29 : Hellinger1 Invalid calculated alpha value: 1.1271303885940402
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=31 : Hellinger1 Invalid calculated alpha value: 1.3131016330785827
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=32 : Hellinger1 Invalid distance value(s): [1.1739096009627814, 1.469304186522535]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=33 : Hellinger1 Invalid calculated alpha value: 1.1117865226115389
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=34 : Hellinger1 Invalid distance value(s): [1.6227368513477545]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=35 : Hellinger1 Invalid calculated alpha value: 1.2220325845705942
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=36 : Hellinger1 Invalid calculated alpha value: 1.0868826087944123
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=38 : Hellinger1 Invalid calculated alpha value: 1.0723561261736954
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=39 : Hellinger1 Invalid distance value(s): [1.3206021534089554]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=40 : Hellinger1 Invalid calculated alpha value: 1.3603837715497078
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=41 : Hellinger1 Invalid distance value(s): [1.0559855124095985]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=42 : Hellinger1 Invalid calculated alpha value: 1.061372433723097
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=44 : Hellinger1 Invalid calculated alpha value: 1.00167946416376
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=45 : Hellinger1 Invalid distance value(s): [1.1408336524960734]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=46 : Hellinger1 Invalid calculated alpha value: 1.2998504894954377
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=49 : Hellinger1 Invalid calculated alpha value: 1.3974971954206687
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=50 : Hellinger1 Invalid distance value(s): [1.5182039684264712]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=51 : Hellinger1 Invalid calculated alpha value: 1.2516659449400993
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=52 : Hellinger1 Invalid distance value(s): [1.706841284157797]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=53 : Hellinger1 Invalid calculated alpha value: 1.102887635268797
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=54 : Hellinger1 Invalid distance value(s): [1.458922375307532]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=55 : Hellinger1 Invalid calculated alpha value: 1.0345436100706187
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=56 : Hellinger1 Invalid distance value(s): [1.141067159540122, 1.0476570119847164]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=57 : Hellinger1 Invalid calculated alpha value: 1.2117069074876934
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=59 : Hellinger1 Invalid calculated alpha value: 1.3150895980310775
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=60 : Hellinger1 Invalid distance value(s): [1.6820453994817215]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=61 : Hellinger1 Invalid calculated alpha value: 1.1578115176858463
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=62 : Hellinger1 Invalid distance value(s): [1.0681550220125864, 1.1462580599062835]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=63 : Hellinger1 Invalid calculated alpha value: 1.347353043907581
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=64 : Hellinger1 Invalid distance value(s): [1.0142631570028129]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=65 : Hellinger1 Invalid calculated alpha value: 1.1267742900086501
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=66 : Hellinger1 Invalid distance value(s): [1.1354390718614218]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=67 : Hellinger1 Invalid calculated alpha value: 1.1483601047648375
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=68 : Hellinger1 Invalid distance value(s): [1.3372277186222705, 1.6726678519714018]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=68 : Hellinger1 Invalid calculated alpha value: -0.09073422292374089
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=69 : Hellinger1 Invalid calculated alpha value: 1.3412906144860233
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=70 : Hellinger1 Invalid distance value(s): [1.218083052029396]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=71 : Hellinger1 Invalid calculated alpha value: 1.1094588439768798
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=72 : Hellinger1 Invalid distance value(s): [1.3537257661110282]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=73 : Hellinger1 Invalid calculated alpha value: 1.2183316279375827
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=74 : Hellinger1 Invalid distance value(s): [1.4416893524345984]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=75 : Hellinger1 Invalid calculated alpha value: 1.1944126146172065
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=77 : Hellinger1 Invalid calculated alpha value: 1.2582132131918766
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=78 : Hellinger1 Invalid distance value(s): [1.1680016953918415, 1.301364395447612]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=79 : Hellinger1 Invalid calculated alpha value: 1.1063038229754083
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=80 : Hellinger1 Invalid distance value(s): [1.049375044330072]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=82 : Hellinger1 Invalid distance value(s): [1.0172928988619927]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=83 : Hellinger1 Invalid calculated alpha value: 1.2622040857041998
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=85 : Hellinger1 Invalid calculated alpha value: 1.3880091321312273
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=87 : Hellinger1 Invalid calculated alpha value: 1.1893783487611373
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=89 : Hellinger1 Invalid distance value(s): [1.2544221608576578]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=90 : Hellinger1 Invalid calculated alpha value: 1.149062443836196
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=92 : Hellinger1 Invalid calculated alpha value: 1.0787194166484186
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=93 : Hellinger1 Invalid distance value(s): [1.0713482498548148]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=94 : Hellinger1 Invalid calculated alpha value: 1.2769044483030874
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [1.032422039502398]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=96 : Hellinger1 Invalid calculated alpha value: 1.301240918703899
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=97 : Hellinger1 Invalid distance value(s): [1.6393443584424519]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=98 : Hellinger1 Invalid calculated alpha value: 1.329296824083277
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=99 : Hellinger1 Invalid distance value(s): [1.3473337984973408]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean Alpha=0.51 | Std ALpha=0.04
# [0.4923847468505518, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.39436921392422286, 0.43458066448682553, 0.3756628470295874, 0.33605711310747555, 0.2313540103406142]
# Execution time:  0.8529554008154179
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8714508178595786
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.832721101066376
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8251413639172664
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.001 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8267182080084385
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.871952484431386
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8733271690236926
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8222075630667653
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean Alpha=0.50 | Std ALpha=0.00
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
# Execution time:  0.8354580296664409
# Average error: 68.03999999999999
# Average macro-F1: 0.21230904980189721
# Average micro-F1: 0.32020000000000004
# Average Accuracy:  31.96
# Standard Deviation:  8.125729136514458
# Variance:  66.027474
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: -27.40909366706294
# Error reduction: -36.26837396711392
# Error reduction: -11.056178664287605
# Error reduction: -28.17832270765026
# Error reduction: -30.95837893350652
# Error reduction: -23.64407370036699
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
# Error reduction: -28.17832270765026
