# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load2CHT(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 12, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 12, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 12, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 12, 0.9, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 2)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '2CHT', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:59: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Two Classes Horizontal Translation. 2 Dimensional data.
# 100 batches of 152 instances
#
#
#
# METHOD: Static lp as classifier
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Execution time:  0.6217032
# Average MCC:  0.09613082970634494
# Average error: 46.25679999999999
# Average macro-F1: 0.39114198886811075
# Average micro-F1: 0.5335
# Average Accuracy:  53.74320000000001
# Standard Deviation:  9.505998935409156
# Variance:  90.36401576000002
# METHOD: Sliding lp as classifier
# Execution time:  0.844984
# Average MCC:  0.02459959446125753
# Average error: 49.000400000000006
# Average macro-F1: 0.3475529914274557
# Average micro-F1: 0.5067999999999999
# Average Accuracy:  50.999599999999994
# Standard Deviation:  5.791726671727526
# Variance:  33.544097840000006
# METHOD: Incremental lp as classifier
# Execution time:  11.8314013
# Average MCC:  0.09346272671449443
# Average error: 46.27009999999999
# Average macro-F1: 0.3902459188997874
# Average micro-F1: 0.533
# Average Accuracy:  53.72990000000001
# Standard Deviation:  9.502005945588541
# Variance:  90.28811698999999
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  0.8800800999999989
# Average MCC:  0.7426425306254505
# Average error: 13.770100000000014
# Average macro-F1: 0.8601056145650047
# Average micro-F1: 0.8637
# Average Accuracy:  86.22989999999999
# Standard Deviation:  4.876439786360537
# Variance:  23.77966499
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=1 : Hellinger1 Invalid distance value(s): [1.190370219441037, 1.1895182552919985]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=3 : Hellinger1 Invalid distance value(s): [1.719061031571211, 1.6988539893834698]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=3 : Hellinger1 Invalid calculated alpha value: -0.2947439481042451
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=5 : Hellinger1 Invalid calculated alpha value: 1.0087829364098955
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=7 : Hellinger1 Invalid calculated alpha value: 1.1122056193462182
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=8 : Hellinger1 Invalid distance value(s): [1.2738027544761508, 1.0337913479086769]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: 1.1668801745868316
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=10 : Hellinger1 Invalid distance value(s): [1.1363510508261945, 1.1231884329985566]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=12 : Hellinger1 Invalid distance value(s): [1.8377980369910145, 1.165984591037606]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=12 : Hellinger1 Invalid calculated alpha value: -0.08767775164121505
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=14 : Hellinger1 Invalid distance value(s): [1.6481489845820967]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=15 : Hellinger1 Invalid calculated alpha value: 1.137361166029348
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=16 : Hellinger1 Invalid distance value(s): [1.303617037009556, 1.199550773991314]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=17 : Hellinger1 Invalid calculated alpha value: 1.2181886310428829
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=18 : Hellinger1 Invalid distance value(s): [1.2605767630369993, 1.4128416532857766]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=19 : Hellinger1 Invalid calculated alpha value: 1.136286176741335
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=20 : Hellinger1 Invalid distance value(s): [1.3368877279923244, 1.5224109997890043]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=20 : Hellinger1 Invalid calculated alpha value: -0.01543580151756907
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=21 : Hellinger1 Invalid calculated alpha value: 1.3313261795530016
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=22 : Hellinger1 Invalid distance value(s): [1.2532060085236274, 1.3746160951640018]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=23 : Hellinger1 Invalid calculated alpha value: 1.2091602929113032
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=24 : Hellinger1 Invalid distance value(s): [1.2193973249899324, 1.4840027392687944]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=25 : Hellinger1 Invalid calculated alpha value: 1.105151042526633
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=26 : Hellinger1 Invalid distance value(s): [1.306372871989435, 1.8239937881738886]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=26 : Hellinger1 Invalid calculated alpha value: -0.15096976770856663
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=27 : Hellinger1 Invalid calculated alpha value: 1.240690343154118
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=28 : Hellinger1 Invalid distance value(s): [1.3605742400034029, 1.3278854037115078]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=30 : Hellinger1 Invalid distance value(s): [1.4812737815984314, 1.4798729938983761]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=30 : Hellinger1 Invalid calculated alpha value: -0.0663598253753086
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=32 : Hellinger1 Invalid distance value(s): [1.177521627337542, 1.5308346494062397]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=33 : Hellinger1 Invalid calculated alpha value: 1.1671887560811194
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=34 : Hellinger1 Invalid distance value(s): [1.745576444015332, 1.35257702448555]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=34 : Hellinger1 Invalid calculated alpha value: -0.13486317187734587
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=35 : Hellinger1 Invalid calculated alpha value: 1.2543646740948051
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=36 : Hellinger1 Invalid distance value(s): [1.0697051665121566, 1.4949880797038608]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=37 : Hellinger1 Invalid calculated alpha value: 1.3646931557010038
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=38 : Hellinger1 Invalid distance value(s): [1.3332414173418523, 1.055509649085465]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=39 : Hellinger1 Invalid calculated alpha value: 1.1244017317234172
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=41 : Hellinger1 Invalid calculated alpha value: 1.1378998088765195
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=42 : Hellinger1 Invalid calculated alpha value: 1.1161444872655684
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=43 : Hellinger1 Invalid distance value(s): [1.2218403248089391, 1.5666086648233692]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=44 : Hellinger1 Invalid distance value(s): [1.4327701792136696]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=45 : Hellinger1 Invalid distance value(s): [1.6764145551356078, 1.319958184298601]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=45 : Hellinger1 Invalid calculated alpha value: -0.08397280734400936
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=46 : Hellinger1 Invalid distance value(s): [1.421826381749462, 1.1833021305797207]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=47 : Hellinger1 Invalid distance value(s): [1.1342166914014653, 1.0135510853643126]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=48 : Hellinger1 Invalid distance value(s): [1.2435920259813222, 1.6162026823251825]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=48 : Hellinger1 Invalid calculated alpha value: -0.01568379178015733
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=49 : Hellinger1 Invalid distance value(s): [1.1061430596637776, 1.275187140758877]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=50 : Hellinger1 Invalid distance value(s): [1.4677878645400597]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=51 : Hellinger1 Invalid distance value(s): [2.0872776687612804, 1.4467371776942375]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=51 : Hellinger1 Invalid calculated alpha value: -0.3527938608546639
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=52 : Hellinger1 Invalid distance value(s): [1.7966958411518115]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=53 : Hellinger1 Invalid distance value(s): [1.1549624840486976, 1.38896043216519]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=54 : Hellinger1 Invalid distance value(s): [1.2943973339092458, 1.2210472618920485]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=55 : Hellinger1 Invalid distance value(s): [1.6411322328140923, 1.4540455411741424]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=55 : Hellinger1 Invalid calculated alpha value: -0.1333753246210223
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=56 : Hellinger1 Invalid distance value(s): [1.7189418841666773]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=57 : Hellinger1 Invalid distance value(s): [1.5412950515473003, 1.4986634435675816]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=57 : Hellinger1 Invalid calculated alpha value: -0.10576568518434581
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=58 : Hellinger1 Invalid distance value(s): [1.399471191932998]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=59 : Hellinger1 Invalid distance value(s): [1.0322234131796613, 1.631062480425868]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=60 : Hellinger1 Invalid distance value(s): [1.5170248372618587]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=61 : Hellinger1 Invalid distance value(s): [1.697013926728656]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=62 : Hellinger1 Invalid distance value(s): [1.2999460839385, 1.8951076449410604]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=62 : Hellinger1 Invalid calculated alpha value: -0.18331330206668506
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=63 : Hellinger1 Invalid distance value(s): [1.7708281533158354]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=64 : Hellinger1 Invalid distance value(s): [1.007822920799588, 1.0343768723401692]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=65 : Hellinger1 Invalid distance value(s): [1.3704038443275086, 1.5134287523760162]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=65 : Hellinger1 Invalid calculated alpha value: -0.027702735978667237
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=66 : Hellinger1 Invalid distance value(s): [1.700721123817808]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=67 : Hellinger1 Invalid distance value(s): [1.2518017415612068]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=68 : Hellinger1 Invalid distance value(s): [1.3569570973637863, 1.5955427200239556]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=68 : Hellinger1 Invalid calculated alpha value: -0.062036346320775815
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=69 : Hellinger1 Invalid distance value(s): [1.0918810396222682, 1.4806516379011778]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=70 : Hellinger1 Invalid distance value(s): [1.278057288131214, 1.4963344366174205]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=71 : Hellinger1 Invalid distance value(s): [1.427549697161944, 1.1667002792344303]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=72 : Hellinger1 Invalid distance value(s): [1.1383549469447676]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=73 : Hellinger1 Invalid distance value(s): [1.6990256113179762, 1.8370959240380358]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=73 : Hellinger1 Invalid calculated alpha value: -0.3538472053049109
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=74 : Hellinger1 Invalid distance value(s): [1.1591060306471164, 1.7739608551551918]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=74 : Hellinger1 Invalid calculated alpha value: -0.052319880528058915
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=75 : Hellinger1 Invalid distance value(s): [1.5070081822665555, 1.7176243422579778]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=75 : Hellinger1 Invalid calculated alpha value: -0.1981026998891715
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=76 : Hellinger1 Invalid distance value(s): [1.1526626634911006, 1.8742687334425445]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=76 : Hellinger1 Invalid calculated alpha value: -0.09925213609372752
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=77 : Hellinger1 Invalid distance value(s): [1.2912928930169374, 1.6106876766966123]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=77 : Hellinger1 Invalid calculated alpha value: -0.03677672248367969
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=78 : Hellinger1 Invalid distance value(s): [1.370791639632864, 1.538993430585348]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=78 : Hellinger1 Invalid calculated alpha value: -0.04067897273601084
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=79 : Hellinger1 Invalid distance value(s): [1.4773041735922807]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=80 : Hellinger1 Invalid distance value(s): [1.1389437623198602, 1.1281922855431668]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=81 : Hellinger1 Invalid distance value(s): [1.0750478474540108, 1.2224073225591794]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=82 : Hellinger1 Invalid distance value(s): [1.4359063966738128, 1.0464122873747927]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=83 : Hellinger1 Invalid distance value(s): [1.2057776223203265, 1.4725913556788461]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=84 : Hellinger1 Invalid distance value(s): [1.0875423772057051, 1.413604266118067]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=85 : Hellinger1 Invalid distance value(s): [1.0291275197297851, 1.7287657839828017]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=86 : Hellinger1 Invalid distance value(s): [1.0902732155414718]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=87 : Hellinger1 Invalid distance value(s): [1.7981224625872403]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=88 : Hellinger1 Invalid distance value(s): [1.0263140579901506, 1.4496451075181627]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=89 : Hellinger1 Invalid distance value(s): [1.3306106598982028, 1.4929872409438356]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=90 : Hellinger1 Invalid distance value(s): [1.0610790039941844]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=91 : Hellinger1 Invalid distance value(s): [1.327413221656177, 1.3472562742876608]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=93 : Hellinger1 Invalid distance value(s): [1.6088766124596026, 1.4315119093714006]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=93 : Hellinger1 Invalid calculated alpha value: -0.10598069854240655
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=94 : Hellinger1 Invalid distance value(s): [1.390547177397929, 1.911242059673217]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=94 : Hellinger1 Invalid calculated alpha value: -0.23668105616247792
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [2.0113188148664314]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=96 : Hellinger1 Invalid distance value(s): [1.3231417116732855, 1.4479804778728051]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=97 : Hellinger1 Invalid distance value(s): [1.1145103694645726, 1.3889536555822877]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=98 : Hellinger1 Invalid distance value(s): [1.1377430382101814, 1.4903034754038305]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=99 : Hellinger1 Invalid distance value(s): [1.0537688354755994, 1.1395147807008938]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.41 | Std keeping percentage=0.16
# Execution time:  2.243367899999999
# Average MCC:  0.23502994103948827
# Average error: 39.5921
# Average macro-F1: 0.4939590667122368
# Average micro-F1: 0.6015
# Average Accuracy:  60.4079
# Standard Deviation:  14.113568952961543
# Variance:  199.19282859
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.22 | Std keeping percentage=0.05
# Execution time:  1.9381439
# Average MCC:  0.5856802403445921
# Average error: 23.486499999999992
# Average macro-F1: 0.7459006764509006
# Average micro-F1: 0.7685
# Average Accuracy:  76.51350000000001
# Standard Deviation:  9.607125103276214
# Variance:  92.29685275000001
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.20 | Std keeping percentage=0.07
# Execution time:  1.064602500000003
# Average MCC:  0.3553177518329983
# Average error: 33.3622
# Average macro-F1: 0.6609348049197646
# Average micro-F1: 0.6712
# Average Accuracy:  66.6378
# Standard Deviation:  27.950572429916345
# Variance:  781.2344991599997
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.21 | Std keeping percentage=0.09
# Execution time:  1.055855000000001
# Average MCC:  0.6858527713590535
# Average error: 17.62509999999999
# Average macro-F1: 0.8193379193066821
# Average micro-F1: 0.8279999999999997
# Average Accuracy:  82.37490000000001
# Standard Deviation:  6.739073006727261
# Variance:  45.41510499
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.25 | Std keeping percentage=0.13
# Execution time:  1.485638999999999
# Average MCC:  0.6417689904493313
# Average error: 20.1053
# Average macro-F1: 0.7862809825203145
# Average micro-F1: 0.8001999999999999
# Average Accuracy:  79.8947
# Standard Deviation:  7.639574000557885
# Variance:  58.363090910000004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.49 | Std keeping percentage=0.04
# Execution time:  1.3475640999999996
# Average MCC:  0.044709792168543004
# Average error: 48.3359
# Average macro-F1: 0.35975123533970554
# Average micro-F1: 0.5137999999999999
# Average Accuracy:  51.6641
# Standard Deviation:  6.591891245310406
# Variance:  43.45303018999998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  1.7460602999999963
# Average MCC:  0.723813575133525
# Average error: 14.717100000000016
# Average macro-F1: 0.8488555080279745
# Average micro-F1: 0.8532000000000001
# Average Accuracy:  85.28289999999998
# Standard Deviation:  5.011755040901341
# Variance:  25.11768859
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.16 | Std keeping percentage=0.05
# Execution time:  1.1539100000000033
# Average MCC:  0.7150945567525255
# Average error: 15.55940000000001
# Average macro-F1: 0.8422510139178556
# Average micro-F1: 0.8466999999999999
# Average Accuracy:  84.44059999999999
# Standard Deviation:  5.164144037495468
# Variance:  26.66838364
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.17 | Std keeping percentage=0.06
# Execution time:  1.3401586000000023
# Average MCC:  0.7085583783861622
# Average error: 16.05920000000002
# Average macro-F1: 0.8371633211862155
# Average micro-F1: 0.8425
# Average Accuracy:  83.94079999999998
# Standard Deviation:  5.52990283458941
# Variance:  30.57982535999999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.08
# Execution time:  1.1900282000000004
# Average MCC:  0.35229366597057366
# Average error: 33.04610000000001
# Average macro-F1: 0.6614666552786503
# Average micro-F1: 0.6729
# Average Accuracy:  66.95389999999999
# Standard Deviation:  28.177222215647873
# Variance:  793.95585179
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: -5.105017937153007
# Error reduction: -0.024747316869856976
# Error reduction: 60.44801947037015
# Error reduction: 12.401010732520557
# Error reduction: 42.3687089715536
# Error reduction: 23.99298888045369
# Error reduction: 53.27501897914526
# Error reduction: 48.660109558046386
# Error reduction: -3.8685824439185064
# Error reduction: 58.68593608121579
# Error reduction: 57.1186680361422
# Error reduction: 56.18868991798026
# Error reduction: 24.581156313728954
