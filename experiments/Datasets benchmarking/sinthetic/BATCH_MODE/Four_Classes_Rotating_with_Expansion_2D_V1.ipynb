# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = False
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load4CRE_V1(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 9, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 9, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 9, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 9, 0.65, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 9, None, "kde", sslClassifier, 'BBD', beta=10)

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 9)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '4CRE-V1', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\BRUNO\Desktop\TCC\AMANDA\setup.py:189: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Four Classes Rotating with Expansion V1. Bidimensional.
# 100 batches of 1187 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  4.0889586
# Average error: 77.6979
# Average macro-F1: 0.21006612796387675
# Average micro-F1: 0.21080000000000002
# Average Accuracy:  22.302099999999992
# Standard Deviation:  35.079015074400246
# Variance:  1230.5372985899996
# METHOD: Sliding lp as classifier
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Execution time:  3.2855564
# Average error: 78.5812
# Average macro-F1: 0.1875552129703933
# Average micro-F1: 0.20819999999999997
# Average Accuracy:  21.4188
# Standard Deviation:  30.44919898059717
# Variance:  927.1537185599998
# METHOD: Incremental lp as classifier
# Execution time:  108.59640189999999
# Average error: 78.2751
# Average macro-F1: 0.20481298544447296
# Average micro-F1: 0.20559999999999998
# Average Accuracy:  21.7249
# Standard Deviation:  34.95375214465537
# Variance:  1221.7647889899997
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  18.422388200000015
# Average error: 77.6486
# Average macro-F1: 0.21680950478742125
# Average micro-F1: 0.22210000000000002
# Average Accuracy:  22.351399999999998
# Standard Deviation:  35.90040757484516
# Variance:  1288.8392640399998
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=0 : Hellinger1 Invalid calculated alpha value: 1.1281106706795425
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=1 : Hellinger1 Invalid distance value(s): [1.0467521142358034]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=2 : Hellinger1 Invalid distance value(s): [1.0627431028795258]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=3 : Hellinger1 Invalid calculated alpha value: 1.2169850409489906
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=4 : Hellinger1 Invalid distance value(s): [1.6786480555920869, 1.505628050549426]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=4 : Hellinger1 Invalid calculated alpha value: -0.17792449069766136
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=9 : Hellinger1 Invalid distance value(s): [1.388946697113071, 1.5556654289971203]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=9 : Hellinger1 Invalid calculated alpha value: -0.05809250068200056
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=10 : Hellinger1 Invalid distance value(s): [1.187201523845238]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=12 : Hellinger1 Invalid calculated alpha value: 1.0157114901611126
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=14 : Hellinger1 Invalid calculated alpha value: 1.040028084902485
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=15 : Hellinger1 Invalid distance value(s): [1.290401749187961, 1.134821397741276]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=16 : Hellinger1 Invalid calculated alpha value: 1.1533830630252115
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=17 : Hellinger1 Invalid calculated alpha value: 1.0730453141758964
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=22 : Hellinger1 Invalid calculated alpha value: 1.0677318283407127
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=23 : Hellinger1 Invalid calculated alpha value: 1.0562395046588675
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=26 : Hellinger1 Invalid distance value(s): [1.1421829381872937]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=30 : Hellinger1 Invalid distance value(s): [1.0736084916232076, 1.4221445251729794]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=31 : Hellinger1 Invalid distance value(s): [1.1673717779490174]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=32 : Hellinger1 Invalid distance value(s): [1.058647438918109]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=33 : Hellinger1 Invalid distance value(s): [1.2613030174051207]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=34 : Hellinger1 Invalid calculated alpha value: 1.2124901291102488
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=38 : Hellinger1 Invalid calculated alpha value: 1.1008745436048968
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=39 : Hellinger1 Invalid calculated alpha value: 1.0901498635942994
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=43 : Hellinger1 Invalid calculated alpha value: 1.3878713797625124
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=47 : Hellinger1 Invalid distance value(s): [1.2542164799277364]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=49 : Hellinger1 Invalid calculated alpha value: 1.031728674188467
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=52 : Hellinger1 Invalid distance value(s): [1.2199510191129503, 1.1392036096372262]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=55 : Hellinger1 Invalid calculated alpha value: 1.3961710712903637
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=57 : Hellinger1 Invalid distance value(s): [1.0665378827245569]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=58 : Hellinger1 Invalid calculated alpha value: 1.3525027868827642
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=59 : Hellinger1 Invalid calculated alpha value: 1.0354883714685073
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=60 : Hellinger1 Invalid calculated alpha value: 1.074984834440342
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=62 : Hellinger1 Invalid distance value(s): [1.3725940051867502, 1.607017612733748]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=62 : Hellinger1 Invalid calculated alpha value: -0.07559224658715391
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=63 : Hellinger1 Invalid distance value(s): [1.2844930013654037, 1.289783049541139]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=64 : Hellinger1 Invalid calculated alpha value: 1.107168567396373
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=65 : Hellinger1 Invalid calculated alpha value: 1.0478598533043042
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=67 : Hellinger1 Invalid distance value(s): [1.0145112212971854, 1.0756931486666015]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=70 : Hellinger1 Invalid calculated alpha value: 1.0333838281853875
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=71 : Hellinger1 Invalid calculated alpha value: 1.1563064251287214
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=72 : Hellinger1 Invalid distance value(s): [1.0352240737314753]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=73 : Hellinger1 Invalid distance value(s): [1.213820502722685]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=74 : Hellinger1 Invalid distance value(s): [1.1078406299847368]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=75 : Hellinger1 Invalid calculated alpha value: 1.041530693448543
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=76 : Hellinger1 Invalid calculated alpha value: 1.0589032187574414
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=77 : Hellinger1 Invalid calculated alpha value: 1.1533481223346616
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=78 : Hellinger1 Invalid distance value(s): [1.0161979634294254]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=79 : Hellinger1 Invalid calculated alpha value: 1.2286955653203708
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=80 : Hellinger1 Invalid calculated alpha value: 1.2616702066225989
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=81 : Hellinger1 Invalid calculated alpha value: 1.0277166369763764
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=83 : Hellinger1 Invalid distance value(s): [1.4961423032177794, 1.5555956739361694]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=83 : Hellinger1 Invalid calculated alpha value: -0.11165542620387936
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=84 : Hellinger1 Invalid distance value(s): [1.1820552283909749]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=86 : Hellinger1 Invalid calculated alpha value: 1.2442161159297032
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=87 : Hellinger1 Invalid calculated alpha value: 1.0980366721324235
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=88 : Hellinger1 Invalid distance value(s): [1.1245965641943945, 1.3693734711248062]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=91 : Hellinger1 Invalid calculated alpha value: 1.1439185194780286
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=93 : Hellinger1 Invalid distance value(s): [1.1287004331566861]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:77: UserWarning: t=95 : Hellinger1 Invalid distance value(s): [1.5967967314545106, 1.6758878258558059]
#   warnings.warn("t={} : Hellinger1 Invalid distance value(s): {}".format(t,filtered))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=95 : Hellinger1 Invalid calculated alpha value: -0.2221287162820631
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=97 : Hellinger1 Invalid calculated alpha value: 1.339351832864474
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# C:\Users\BRUNO\Desktop\TCC\AMANDA\methods\amanda_dynamic.py:80: UserWarning: t=99 : Hellinger1 Invalid calculated alpha value: 1.2272425662929334
#   warnings.warn("t={} : Hellinger1 Invalid calculated alpha value: {}".format(t,alpha))
# AMANDA-DCP Hellinger | Mean keeping percentage=0.25 | Std keeping percentage=0.17
# Execution time:  15.155818199999999
# Average error: 80.66810000000001
# Average macro-F1: 0.1864336388632114
# Average micro-F1: 0.19210000000000002
# Average Accuracy:  19.331899999999997
# Standard Deviation:  34.01819133037499
# Variance:  1157.23734139
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.27 | Std keeping percentage=0.10
# Execution time:  14.604104199999995
# Average error: 76.3734
# Average macro-F1: 0.20367663094568925
# Average micro-F1: 0.2409
# Average Accuracy:  23.6266
# Standard Deviation:  27.929980029351974
# Variance:  780.08378444
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.10
# Execution time:  13.883874099999986
# Average error: 76.8576
# Average macro-F1: 0.19609550410142407
# Average micro-F1: 0.2296
# Average Accuracy:  23.1424
# Standard Deviation:  28.62987429661542
# Variance:  819.6697022400002
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.21 | Std keeping percentage=0.11
# Execution time:  14.216379200000006
# Average error: 78.5804
# Average macro-F1: 0.1745454632067333
# Average micro-F1: 0.21010000000000006
# Average Accuracy:  21.4196
# Standard Deviation:  26.581289581959716
# Variance:  706.5649558400002
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.24 | Std keeping percentage=0.14
# Execution time:  13.920623000000006
# Average error: 78.583
# Average macro-F1: 0.17454139474895541
# Average micro-F1: 0.21340000000000003
# Average Accuracy:  21.416999999999998
# Standard Deviation:  25.19358781515646
# Variance:  634.716867
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.41 | Std keeping percentage=0.11
# Execution time:  14.198363
# Average error: 77.54260000000001
# Average macro-F1: 0.18404234628852253
# Average micro-F1: 0.2181
# Average Accuracy:  22.457399999999996
# Standard Deviation:  26.39189817425037
# Variance:  696.5322892400001
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  14.203884099999982
# Average error: 78.80449999999999
# Average macro-F1: 0.213141055359309
# Average micro-F1: 0.2134
# Average Accuracy:  21.195500000000003
# Standard Deviation:  38.44987909928976
# Variance:  1478.3932027499995
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.14 | Std keeping percentage=0.05
# Execution time:  14.050225700000027
# Average error: 76.4941
# Average macro-F1: 0.23644058790717928
# Average micro-F1: 0.23689999999999997
# Average Accuracy:  23.5059
# Standard Deviation:  39.04901814629915
# Variance:  1524.82581819
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.15 | Std keeping percentage=0.06
# Execution time:  13.928249300000004
# Average error: 76.7349
# Average macro-F1: 0.23375022547855345
# Average micro-F1: 0.23409999999999997
# Average Accuracy:  23.265100000000004
# Standard Deviation:  38.970798490536474
# Variance:  1518.7231349899998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.17 | Std keeping percentage=0.08
# Execution time:  14.297055300000011
# Average error: 76.8803
# Average macro-F1: 0.2315934677721819
# Average micro-F1: 0.23189999999999997
# Average Accuracy:  23.1197
# Standard Deviation:  38.81827024623844
# Variance:  1506.8581049100007
# C:\Users\BRUNO\Anaconda3\envs\datascience36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Error reduction: -3.960613574506399
# Error reduction: -2.588097085027826
# Error reduction: 0.22105541630611428
# Error reduction: -13.318028347106308
# Error reduction: 5.9389026145520285
# Error reduction: 3.767806619107647
# Error reduction: -3.957026468359453
# Error reduction: -3.96868456333706
# Error reduction: 0.696346980777613
# Error reduction: -4.961864577775142
# Error reduction: 5.397697974630231
# Error reduction: 4.317979024396859
# Error reduction: 3.6660224821878193
