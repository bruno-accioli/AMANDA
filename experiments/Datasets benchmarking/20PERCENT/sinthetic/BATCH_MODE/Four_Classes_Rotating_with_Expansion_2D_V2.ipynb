# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[4])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = False
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load4CRE_V2(path, sep)
    
    # 5% of initial labeled data
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 12, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 12, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 12, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 12, 0.9, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 2, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 2, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    lastIndex = list(experiments.keys())[-1]
    betas = [-50, -1, -0.5, -0.1, 1.001, 1.1, 2, 3, 5, 10, 50]
    bestK = [2, 12, 12, 2, 12, 12, 12, 12, 12, 12, 12]
    for i in range(len(betas)):
        experiments[lastIndex+1+i] = Experiment(amanda_dynamic, bestK[i], None, "kde", sslClassifier, 'BBD', beta=betas[i])
        
    # Proposed method 5 (AMANDA - DCP HDDDM)
    experiments[17] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'HDDDM')

    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 9)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '4CRE-V2', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# Four Classes Rotating with Expansion V2. Bidimensional.
# 100 batches of 1738 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  3.5858674599999176
# Average error: 79.5616
# Average macro-F1: 0.20385538705629735
# Average micro-F1: 0.2052
# Average Accuracy:  20.438400000000005
# Standard Deviation:  31.24194554505209
# Variance:  976.0591614400001
# METHOD: Sliding lp as classifier
# Execution time:  2.721155782999972
# Average error: 82.9671
# Average macro-F1: 0.12551605519547487
# Average micro-F1: 0.1802
# Average Accuracy:  17.0329
# Standard Deviation:  19.73197639847565
# Variance:  389.35089259
# METHOD: Incremental lp as classifier
# Execution time:  130.06257248199995
# Average error: 79.8805
# Average macro-F1: 0.19995313997696723
# Average micro-F1: 0.20129999999999998
# Average Accuracy:  20.1195
# Standard Deviation:  30.96822246674807
# Variance:  959.0308027499999
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  19.018001740000045
# Average error: 83.9435
# Average macro-F1: 0.16907295895235436
# Average micro-F1: 0.17009999999999997
# Average Accuracy:  16.0565
# Standard Deviation:  29.638343994730874
# Variance:  878.4314347499997
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# AMANDA-DCP Hellinger | Mean keeping percentage=0.29 | Std keeping percentage=0.19
# Execution time:  19.517271779999987
# Average error: 78.094
# Average macro-F1: 0.20295089544442413
# Average micro-F1: 0.21320000000000003
# Average Accuracy:  21.906000000000002
# Standard Deviation:  19.662061641648876
# Variance:  386.5966680000001
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.16 | Std keeping percentage=0.04
# Execution time:  19.66299801799994
# Average error: 81.7796
# Average macro-F1: 0.1677257510329185
# Average micro-F1: 0.17509999999999998
# Average Accuracy:  18.220399999999998
# Standard Deviation:  14.709204119869979
# Variance:  216.36068583999995
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -50.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  19.808252351999954
# Average error: 82.9202
# Average macro-F1: 0.17024247196665196
# Average micro-F1: 0.1728
# Average Accuracy:  17.0798
# Standard Deviation:  28.236247519102108
# Variance:  797.2856739599999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -1.000 | Mean keeping percentage=0.15 | Std keeping percentage=0.05
# Execution time:  20.064891904000092
# Average error: 71.7361
# Average macro-F1: 0.24876293990984824
# Average micro-F1: 0.2859
# Average Accuracy:  28.263900000000007
# Standard Deviation:  28.49993869800425
# Variance:  812.2465057900002
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.16 | Std keeping percentage=0.06
# Execution time:  19.63274940000008
# Average error: 74.03280000000001
# Average macro-F1: 0.22956849890970019
# Average micro-F1: 0.2604
# Average Accuracy:  25.9672
# Standard Deviation:  29.213077485263344
# Variance:  853.4038961600002
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.100 | Mean keeping percentage=0.21 | Std keeping percentage=0.12
# Execution time:  18.566897238000024
# Average error: 75.22070000000001
# Average macro-F1: 0.24640065257774224
# Average micro-F1: 0.2492
# Average Accuracy:  24.779299999999992
# Standard Deviation:  35.40885954828255
# Variance:  1253.7873345100004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.001 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  18.307920785999954
# Average error: 83.9435
# Average macro-F1: 0.16907295895235436
# Average micro-F1: 0.17009999999999997
# Average Accuracy:  16.0565
# Standard Deviation:  29.638343994730874
# Variance:  878.4314347499997
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.100 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  18.488201378999975
# Average error: 83.9435
# Average macro-F1: 0.16907295895235436
# Average micro-F1: 0.17009999999999997
# Average Accuracy:  16.0565
# Standard Deviation:  29.638343994730874
# Variance:  878.4314347499997
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.01
# Execution time:  18.891908855999986
# Average error: 81.4453
# Average macro-F1: 0.18467624852391598
# Average micro-F1: 0.18469999999999998
# Average Accuracy:  18.5547
# Standard Deviation:  18.724121098465478
# Variance:  350.59271091000005
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 3.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.02
# Execution time:  19.265529641999933
# Average error: 74.9332
# Average macro-F1: 0.23295341024505653
# Average micro-F1: 0.2557
# Average Accuracy:  25.066800000000004
# Standard Deviation:  19.89642510000226
# Variance:  395.86773175999997
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 5.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  19.75063485999999
# Average error: 82.9097
# Average macro-F1: 0.15944310839984005
# Average micro-F1: 0.1607
# Average Accuracy:  17.0903
# Standard Deviation:  30.413089236544188
# Variance:  924.95599691
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  19.791409810000005
# Average error: 80.48689999999999
# Average macro-F1: 0.1934206625618791
# Average micro-F1: 0.1935
# Average Accuracy:  19.5131
# Standard Deviation:  19.666640216112153
# Variance:  386.7767373899999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 50.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.02
# Execution time:  19.799848044999976
# Average error: 83.5137
# Average macro-F1: 0.15276442552722574
# Average micro-F1: 0.15450000000000003
# Average Accuracy:  16.4863
# Standard Deviation:  29.803795652735243
# Variance:  888.2662353100002
# METHOD: lp as classifier and kde and HDDDM distance as dynamic CSE
# AMANDA-DCP HDDDM | Mean keeping percentage=0.48 | Std keeping percentage=0.07
# Execution time:  21.0650312140001
# Average error: 81.6028
# Average macro-F1: 0.09180989350998622
# Average micro-F1: 0.18719999999999998
# Average Accuracy:  18.397199999999998
# Standard Deviation:  11.386683106155191
# Variance:  129.65655216000002
# Pos 14 - Error reduction (Sliding SSL):-16.662263190856443
# Pos 7 - Error reduction (Incremental SSL):-1.560298262094911
# Pos 16 - Error reduction (AMANDA (Fixed)):-21.439545169876332
# Pos 5 - Error reduction (AMANDA-DCP Hellinger):7.180601221230611
# Pos 11 - Error reduction (AMANDA-DCP Hellinger2):-10.852121496790387
# Pos 13 - Error reduction (AMANDA-DCP BBD - β = -50.000):-16.432793173633968
# Pos 1 - Error reduction (AMANDA-DCP BBD - β = -1.000):38.288222170032874
# Pos 2 - Error reduction (AMANDA-DCP BBD - β = -0.500):27.05104117739154
# Pos 4 - Error reduction (AMANDA-DCP BBD - β = -0.100):21.23894238296533
# Pos 16 - Error reduction (AMANDA-DCP BBD - β = 1.001):-21.439545169876332
# Pos 16 - Error reduction (AMANDA-DCP BBD - β = 1.100):-21.439545169876332
# Pos 9 - Error reduction (AMANDA-DCP BBD - β = 2.000):-9.216474870831396
# Pos 3 - Error reduction (AMANDA-DCP BBD - β = 3.000):22.64560826679191
# Pos 12 - Error reduction (AMANDA-DCP BBD - β = 5.000):-16.381419289181174
# Pos 8 - Error reduction (AMANDA-DCP BBD - β = 10.000):-4.527262408016299
# Pos 15 - Error reduction (AMANDA-DCP BBD - β = 50.000):-19.336640832941935
# Pos 10 - Error reduction (AMANDA-DCP HDDDM):-9.987083137623328
