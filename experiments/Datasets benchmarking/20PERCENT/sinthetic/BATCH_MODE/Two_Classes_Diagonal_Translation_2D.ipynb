# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[4])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version
from methods import prequential_amanda_fixed
from methods import prequential_amanda_dynamic
from methods import prequential_static_classifier
from methods import prequential_deslizante_LN
from methods import prequential_incremental_LN
from methods import prequential_compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, nb = naive bayes, knn = k-nn, sgd = stochastic gradient descent
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load2CDT(path, sep)
    
    # 5% of initial labeled data
    labeledData = int(0.5*len(dataLabels))
    
    # Static SSL
    experiments[0] = Experiment(static_classifier, 2, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 2, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 2, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 2, 0.85, "kde", clfName=sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 2, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 6, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    lastIndex = list(experiments.keys())[-1]
    betas = [-50, -1, -0.5, -0.1, 1.001, 1.1, 2, 3, 5, 10, 50]
    bestK = [4, 2, 2, 4, 6, 2, 2, 2, 2, 2, 4]
    for i in range(len(betas)):
        experiments[lastIndex+1+i] = Experiment(amanda_dynamic, bestK[i], None, "kde", sslClassifier, 'BBD', beta=betas[i])
    
    # Proposed method 5 (AMANDA - DCP HDDDM)
    experiments[17] = Experiment(amanda_dynamic, 4, None, "kde", sslClassifier, 'HDDDM')    
    
    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 12)
    
    
    '''
    #prequential evaluation
    steps = 10
    dataValues, dataLabels = dataValues[:labeledData], dataLabels[:labeledData]
    labeledData = int(0.05*len(dataLabels))
    experiments[0] = Experiment(prequential_static_classifier, 12, clfName=sslClassifier)
    experiments[1] = Experiment(prequential_deslizante_LN, 12, clfName=sslClassifier)
    experiments[2] = Experiment(prequential_incremental_LN, 12, clfName=sslClassifier)
    experiments[3] = Experiment(prequential_amanda_fixed, 12, 0.75, "kde", sslClassifier)
    experiments[4] = Experiment(prequential_amanda_dynamic, 9, None, "kde", clfName=sslClassifier)
    experiments[5] = Experiment(prequential_compose_gmm_version, 12, 0.75)
    
    # levelIw matlab results
    predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '2CDT', steps)
    externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw[:labeledData], "accuracies":originalAccsLevelIw[:labeledData], "time":timeLevelIw})
    '''
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# Two Classes Diagonal Translation. 2 Dimensional data
# 100 batches of 80 instances
#
#
#
# METHOD: Static lp as classifier
# Execution time:  0.2477792770000633
# Average MCC:  0.17963628763887363
# Average error: 42.1375
# Average macro-F1: 0.5617270318361776
# Average micro-F1: 0.5786250000000001
# Average Accuracy:  57.8625
# Standard Deviation:  9.969163392682459
# Variance:  99.38421875000003
# METHOD: Sliding lp as classifier
# Execution time:  0.3884621079999988
# Average MCC:  0.1350934984653893
# Average error: 43.975
# Average macro-F1: 0.42292709468721484
# Average micro-F1: 0.56025
# Average Accuracy:  56.025
# Standard Deviation:  13.980320990592453
# Variance:  195.44937499999995
# METHOD: Incremental lp as classifier
# Execution time:  4.379346860000055
# Average MCC:  0.16208494241154792
# Average error: 43.15
# Average macro-F1: 0.5477608081306709
# Average micro-F1: 0.5684999999999999
# Average Accuracy:  56.85
# Standard Deviation:  10.296358579614447
# Variance:  106.01500000000003
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  0.39657134699996277
# Average MCC:  0.6158221511108039
# Average error: 20.112499999999997
# Average macro-F1: 0.7540130737074416
# Average micro-F1: 0.798875
# Average Accuracy:  79.8875
# Standard Deviation:  19.015696641196186
# Variance:  361.5967187499999
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# AMANDA-DCP Hellinger | Mean keeping percentage=0.28 | Std keeping percentage=0.17
# Execution time:  0.5482251690000339
# Average MCC:  -0.28101735649890525
# Average error: 64.4625
# Average macro-F1: 0.3463269528248115
# Average micro-F1: 0.355375
# Average Accuracy:  35.5375
# Standard Deviation:  38.343943051673754
# Variance:  1470.25796875
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.30 | Std keeping percentage=0.08
# Execution time:  0.7399743590000298
# Average MCC:  0.0014121975762272057
# Average error: 49.975
# Average macro-F1: 0.3331217675132394
# Average micro-F1: 0.5002499999999999
# Average Accuracy:  50.025
# Standard Deviation:  4.7761778651972335
# Variance:  22.811875000000004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -50.000 | Mean keeping percentage=0.27 | Std keeping percentage=0.12
# Execution time:  0.5018269569999347
# Average MCC:  0.000992234262979312
# Average error: 49.9875
# Average macro-F1: 0.33288645720854676
# Average micro-F1: 0.5001249999999999
# Average Accuracy:  50.0125
# Standard Deviation:  4.787663182597541
# Variance:  22.921718750000014
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -1.000 | Mean keeping percentage=0.25 | Std keeping percentage=0.10
# Execution time:  0.46512641699996493
# Average MCC:  0.5939981902878511
# Average error: 21.1875
# Average macro-F1: 0.7417159842624522
# Average micro-F1: 0.788125
# Average Accuracy:  78.8125
# Standard Deviation:  18.686036732009278
# Variance:  349.16796874999994
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.24 | Std keeping percentage=0.12
# Execution time:  0.45091275800007224
# Average MCC:  0.8112998917466682
# Average error: 10.349999999999994
# Average macro-F1: 0.8899950047055789
# Average micro-F1: 0.8965
# Average Accuracy:  89.65
# Standard Deviation:  9.727666729488629
# Variance:  94.6275
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.100 | Mean keeping percentage=0.42 | Std keeping percentage=0.08
# Execution time:  0.5844023990000551
# Average MCC:  0.000992234262979312
# Average error: 49.9875
# Average macro-F1: 0.33288645720854676
# Average micro-F1: 0.5001249999999999
# Average Accuracy:  50.0125
# Standard Deviation:  4.787663182597541
# Variance:  22.921718750000014
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.001 | Mean keeping percentage=0.12 | Std keeping percentage=0.03
# Execution time:  0.5108172879999984
# Average MCC:  0.0014121975762272057
# Average error: 49.975
# Average macro-F1: 0.3331217675132394
# Average micro-F1: 0.5002499999999999
# Average Accuracy:  50.025
# Standard Deviation:  4.7761778651972335
# Variance:  22.811875000000004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.100 | Mean keeping percentage=0.13 | Std keeping percentage=0.04
# Execution time:  0.5275945450000563
# Average MCC:  0.8620760820506389
# Average error: 7.4375
# Average macro-F1: 0.9224128929995633
# Average micro-F1: 0.9256250000000001
# Average Accuracy:  92.5625
# Standard Deviation:  7.155362936287719
# Variance:  51.19921875
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.17 | Std keeping percentage=0.07
# Execution time:  0.5180330969999432
# Average MCC:  0.8371088660881252
# Average error: 8.912499999999994
# Average macro-F1: 0.9066946922242636
# Average micro-F1: 0.9108750000000001
# Average Accuracy:  91.0875
# Standard Deviation:  8.007135489674194
# Variance:  64.11421875
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 3.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.09
# Execution time:  0.4523505740000928
# Average MCC:  0.836373172202374
# Average error: 8.9375
# Average macro-F1: 0.9061433877979143
# Average micro-F1: 0.9106250000000001
# Average Accuracy:  91.0625
# Standard Deviation:  8.117063431438737
# Variance:  65.88671875
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 5.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.08
# Execution time:  0.4428158570000278
# Average MCC:  0.7864900192713129
# Average error: 11.612499999999997
# Average macro-F1: 0.8780338290604365
# Average micro-F1: 0.8838750000000002
# Average Accuracy:  88.3875
# Standard Deviation:  10.497462491002292
# Variance:  110.19671875000004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.08
# Execution time:  0.5669332219999887
# Average MCC:  0.8100746745421468
# Average error: 10.375
# Average macro-F1: 0.891202186863995
# Average micro-F1: 0.89625
# Average Accuracy:  89.625
# Standard Deviation:  8.356322456679134
# Variance:  69.828125
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 50.000 | Mean keeping percentage=0.27 | Std keeping percentage=0.12
# Execution time:  0.7060810809999793
# Average MCC:  0.000992234262979312
# Average error: 49.9875
# Average macro-F1: 0.33288645720854676
# Average micro-F1: 0.5001249999999999
# Average Accuracy:  50.0125
# Standard Deviation:  4.787663182597541
# Variance:  22.921718750000014
# METHOD: lp as classifier and kde and HDDDM distance as dynamic CSE
# AMANDA-DCP HDDDM | Mean keeping percentage=0.47 | Std keeping percentage=0.09
# Execution time:  0.5019626680000329
# Average MCC:  0.000992234262979312
# Average error: 49.9875
# Average macro-F1: 0.33288645720854676
# Average micro-F1: 0.5001249999999999
# Average Accuracy:  50.0125
# Standard Deviation:  4.787663182597541
# Variance:  22.921718750000014
# Pos 11 - Error reduction (Sliding SSL):-3.1756318859364847
# Pos 10 - Error reduction (Incremental SSL):-1.749837977964996
# Pos 7 - Error reduction (AMANDA (Fixed)):38.064376755238726
# Pos 18 - Error reduction (AMANDA-DCP Hellinger):-38.58284726722834
# Pos 12 - Error reduction (AMANDA-DCP Hellinger2):-13.545042125729099
# Pos 14 - Error reduction (AMANDA-DCP BBD - β = -50.000):-13.566645063728657
# Pos 8 - Error reduction (AMANDA-DCP BBD - β = -1.000):36.206524087275874
# Pos 4 - Error reduction (AMANDA-DCP BBD - β = -0.500):54.936271332901285
# Pos 14 - Error reduction (AMANDA-DCP BBD - β = -0.100):-13.566645063728657
# Pos 12 - Error reduction (AMANDA-DCP BBD - β = 1.001):-13.545042125729099
# Pos 1 - Error reduction (AMANDA-DCP BBD - β = 1.100):59.96975588680061
# Pos 2 - Error reduction (AMANDA-DCP BBD - β = 2.000):57.4206092028516
# Pos 3 - Error reduction (AMANDA-DCP BBD - β = 3.000):57.37740332685246
# Pos 6 - Error reduction (AMANDA-DCP BBD - β = 5.000):52.75437459494492
# Pos 5 - Error reduction (AMANDA-DCP BBD - β = 10.000):54.89306545690214
# Pos 14 - Error reduction (AMANDA-DCP BBD - β = 50.000):-13.566645063728657
# Pos 14 - Error reduction (AMANDA-DCP HDDDM):-13.566645063728657
