# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, cl = cluster and label, knn = k-nn, svm = svm
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = False
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load5CVT(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))

    # Static SSL
    experiments[0] = Experiment(static_classifier, 8, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 8, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 8, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 8, 0.85, "kde", sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'BBD', beta=10)
    
    # Proposed method 5 (AMANDA - DCP HDDDM)
    experiments[14] = Experiment(amanda_dynamic, 8, None, "kde", sslClassifier, 'HDDDM')


    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 8)
    
    # levelIw matlab results
    #predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '5CVT', steps)
    #externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw, "accuracies":originalAccsLevelIw, "time":timeLevelIw})
    
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\setup.py:163: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Five Classes Vertical Translation. Bidimensional.
# 100 batches of 228 instances
#
#
#
# METHOD: Static lp as classifier
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Execution time:  0.42585652913454003
# Average error: 55.5009
# Average macro-F1: 0.3472425299684842
# Average micro-F1: 0.4428999999999999
# Average Accuracy:  44.4991
# Standard Deviation:  19.10053706548588
# Variance:  364.83051618999997
# METHOD: Sliding lp as classifier
# Execution time:  0.36306497146587546
# Average error: 67.6977
# Average macro-F1: 0.21524739095057113
# Average micro-F1: 0.3234
# Average Accuracy:  32.302299999999995
# Standard Deviation:  9.801528437442807
# Variance:  96.06995971000002
# METHOD: Incremental lp as classifier
# Execution time:  6.648275589662215
# Average error: 55.76380000000001
# Average macro-F1: 0.34344896704254924
# Average micro-F1: 0.43989999999999996
# Average Accuracy:  44.23619999999999
# Standard Deviation:  18.768790093130672
# Variance:  352.2674815600001
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  0.8174378971863359
# Average error: 71.63999999999999
# Average macro-F1: 0.1998931864685713
# Average micro-F1: 0.2852
# Average Accuracy:  28.36000000000001
# Standard Deviation:  14.200706179623602
# Variance:  201.66005599999994
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# AMANDA-DCP Hellinger | Mean keeping percentage=0.21 | Std keeping percentage=0.15
# Execution time:  0.8828161714417391
# Average error: 61.271800000000006
# Average macro-F1: 0.363113643412153
# Average micro-F1: 0.3871
# Average Accuracy:  38.728199999999994
# Standard Deviation:  21.62363495714816
# Variance:  467.5815887599999
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.22 | Std keeping percentage=0.05
# Execution time:  0.802101407874229
# Average error: 75.908
# Average macro-F1: 0.1665587778569672
# Average micro-F1: 0.2408
# Average Accuracy:  24.092
# Standard Deviation:  12.656450845319947
# Variance:  160.185748
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.03
# Execution time:  0.8205132192507438
# Average error: 58.724
# Average macro-F1: 0.3999686640852944
# Average micro-F1: 0.41159999999999997
# Average Accuracy:  41.276
# Standard Deviation:  25.734184852060107
# Variance:  662.2482699999998
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.13 | Std keeping percentage=0.03
# Execution time:  0.859891212970096
# Average error: 47.842300000000016
# Average macro-F1: 0.5138041051955797
# Average micro-F1: 0.5244000000000001
# Average Accuracy:  52.157699999999984
# Standard Deviation:  17.539263260182853
# Variance:  307.62575571
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.15 | Std keeping percentage=0.05
# Execution time:  0.8805224315322526
# Average error: 62.780699999999996
# Average macro-F1: 0.3242440711299416
# Average micro-F1: 0.3712
# Average Accuracy:  37.219300000000004
# Standard Deviation:  21.923759680082245
# Variance:  480.6512385099999
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.39 | Std keeping percentage=0.07
# Execution time:  0.8210279500372124
# Average error: 66.0224
# Average macro-F1: 0.21739232529370076
# Average micro-F1: 0.33949999999999997
# Average Accuracy:  33.977599999999995
# Standard Deviation:  6.489151272701231
# Variance:  42.10908424000001
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  0.8097063608595612
# Average error: 49.1008
# Average macro-F1: 0.5212738016418268
# Average micro-F1: 0.5176999999999999
# Average Accuracy:  50.8992
# Standard Deviation:  15.142410751264148
# Variance:  229.29260336000004
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  0.7985772903265129
# Average error: 62.75020000000001
# Average macro-F1: 0.3476229458311168
# Average micro-F1: 0.3742999999999999
# Average Accuracy:  37.24979999999999
# Standard Deviation:  22.028137233093496
# Variance:  485.23882996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.11 | Std keeping percentage=0.02
# Execution time:  0.8441942565996747
# Average error: 54.83340000000001
# Average macro-F1: 0.4499776962239556
# Average micro-F1: 0.45339999999999997
# Average Accuracy:  45.16659999999999
# Standard Deviation:  20.74877115493831
# Variance:  430.51150444000007
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.12 | Std keeping percentage=0.03
# Execution time:  0.8248254502805814
# Average error: 61.6966
# Average macro-F1: 0.3595714705476851
# Average micro-F1: 0.3867000000000001
# Average Accuracy:  38.3034
# Standard Deviation:  18.294409704606487
# Variance:  334.68542644
# METHOD: lp as classifier and kde and HDDDM distance as dynamic CSE
# AMANDA-DCP HDDDM | Mean keeping percentage=0.45 | Std keeping percentage=0.11
# Execution time:  0.875599676917016
# Average error: 66.14920000000001
# Average macro-F1: 0.23472752432461813
# Average micro-F1: 0.3383
# Average Accuracy:  33.85079999999999
# Standard Deviation:  6.985618466535372
# Variance:  48.79886536
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Pos 13 - Error reduction (Sliding SSL):-27.40909366706294
# Pos 5 - Error reduction (Incremental SSL):-0.5907984655869647
# Pos 14 - Error reduction (AMANDA (Fixed)):-36.26837396711392
# Pos 7 - Error reduction (AMANDA-DCP Hellinger):-12.968576892566377
# Pos 15 - Error reduction (AMANDA-DCP Hellinger2):-45.85957918250032
# Pos 6 - Error reduction (AMANDA-DCP BBD - β = -10.000):-7.243067837327037
# Pos 1 - Error reduction (AMANDA-DCP BBD - β = -2.000):17.21068515992455
# Pos 10 - Error reduction (AMANDA-DCP BBD - β = -0.500):-16.359431988512117
# Pos 11 - Error reduction (AMANDA-DCP BBD - β = -0.010):-23.644298424013076
# Pos 2 - Error reduction (AMANDA-DCP BBD - β = 1.010):14.382538073803744
# Pos 9 - Error reduction (AMANDA-DCP BBD - β = 1.500):-16.290891276452793
# Pos 3 - Error reduction (AMANDA-DCP BBD - β = 2.000):1.5000303376922
# Pos 8 - Error reduction (AMANDA-DCP BBD - β = 10.000):-13.92320294118307
# Pos 12 - Error reduction (AMANDA-DCP HDDDM):-23.929248007263084
