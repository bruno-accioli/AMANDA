# %%
# %matplotlib inline
import sys
import os
from pathlib import Path
os.chdir(Path(os.getcwd()).resolve().parents[3])

import setup
from methods import runExperiments
from methods import static_classifier
from methods import amanda_dynamic
from methods import amanda_fixed
from methods import incremental_LN
from methods import deslizante_LN
from methods import compose_gmm_version
from methods import prequential_amanda_fixed
from methods import prequential_amanda_dynamic
from methods import prequential_static_classifier
from methods import prequential_deslizante_LN
from methods import prequential_incremental_LN
from methods import prequential_compose_gmm_version


class Experiment():
     def __init__(self, method, K=None, excludingPercentage=None, densityFunction=None, clfName=None, distanceMetric=None, beta=None):
        self.method = method
        self.clfName = clfName
        self.densityFunction=densityFunction
        self.excludingPercentage = excludingPercentage
        self.K_variation = K
        self.distanceMetric = distanceMetric
        self.beta = beta


def loadLevelResults(path, sep, key, steps):
    originalAccs, F1s, time = setup.loadLevelIwBoxplotResults(path, sep)
    predictions = F1s[key]
    predictions = [ predictions[i::steps] for i in range(steps) ]
    
    return predictions, originalAccs[key], time[key]


def main():
    experiments = {}
    is_windows = sys.platform.startswith('win')
    sep = '\\'

    if is_windows == False:
        sep = '/'

    path = os.getcwd()+sep+'data'+sep
    
    # SETTINGS
    sslClassifier = 'lp' # lp = label propagation, rf = random forests, nb = naive bayes, knn = k-nn, sgd = stochastic gradient descent
    steps = 100
    poolSize = None
    isBatchMode = True # False = Stream
    isBinaryClassification = True
    isImbalanced = False
    externalResults = []
    
    # Load dataset
    dataValues, dataLabels, description = setup.load2CDT(path, sep)
    
    # Only 5% of initial labeled data - Extreme verification latency scenario
    labeledData = int(0.05*len(dataLabels))
    
    # Static SSL
    experiments[0] = Experiment(static_classifier, 12, clfName=sslClassifier)
    
    # Sliding SSL
    experiments[1] = Experiment(deslizante_LN, 12, clfName=sslClassifier)
    
    # Incremental SSL
    experiments[2] = Experiment(incremental_LN, 12, clfName=sslClassifier)
    
    # Proposed Method 1 (AMANDA - Fixed core extraction percentage)
    experiments[3] = Experiment(amanda_fixed, 12, 0.75, "kde", clfName=sslClassifier)

    # Proposed method 2 (AMANDA - DCP Original)
    experiments[4] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'Hellinger')
    
    # Proposed method 3 (AMANDA - DCP Hellinger2)
    experiments[5] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'Hellinger2')                         
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[6] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=-10)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[7] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=-2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[8] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=-0.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[9] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=-0.01)  
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[10] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=1.01)        
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[11] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=1.5)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[12] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=2)
    
    # Proposed method 4 (AMANDA - DCP BBD)
    experiments[13] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'BBD', beta=10)
    
    # Proposed method 5 (AMANDA - DCP HDDDM)
    experiments[14] = Experiment(amanda_dynamic, 12, None, "kde", sslClassifier, 'HDDDM')    
    
    # COMPOSE GMM (Python version)
    #experiments[5] = Experiment(compose_gmm_version, 12)
    
    
    '''
    #prequential evaluation
    steps = 10
    dataValues, dataLabels = dataValues[:labeledData], dataLabels[:labeledData]
    labeledData = int(0.05*len(dataLabels))
    experiments[0] = Experiment(prequential_static_classifier, 12, clfName=sslClassifier)
    experiments[1] = Experiment(prequential_deslizante_LN, 12, clfName=sslClassifier)
    experiments[2] = Experiment(prequential_incremental_LN, 12, clfName=sslClassifier)
    experiments[3] = Experiment(prequential_amanda_fixed, 12, 0.75, "kde", sslClassifier)
    experiments[4] = Experiment(prequential_amanda_dynamic, 9, None, "kde", clfName=sslClassifier)
    experiments[5] = Experiment(prequential_compose_gmm_version, 12, 0.75)
    
    # levelIw matlab results
    predictionsLevelIw, originalAccsLevelIw, timeLevelIw = loadLevelResults(path, sep, '2CDT', steps)
    externalResults.append({"name":"Level IW", "predictions":predictionsLevelIw[:labeledData], "accuracies":originalAccsLevelIw[:labeledData], "time":timeLevelIw})
    '''
    # Run experiments
    runExperiments.run(dataValues, dataLabels, description, isBinaryClassification, isImbalanced, 
                       experiments, steps, labeledData, isBatchMode, poolSize, externalResults)
    

if __name__ == "__main__":
    main()
# Out:
# C:\Users\bruno.silva\Desktop\TCC\AMANDA\setup.py:46: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   dataValues = pd.DataFrame.as_matrix(dataValues)
# Two Classes Diagonal Translation. 2 Dimensional data
# 100 batches of 152 instances
#
#
#
# METHOD: Static lp as classifier
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Execution time:  0.3390359076818671
# Average MCC:  0.09876324089684951
# Average error: 45.651399999999995
# Average macro-F1: 0.3964631435983781
# Average micro-F1: 0.5403000000000001
# Average Accuracy:  54.348600000000005
# Standard Deviation:  11.443006075328285
# Variance:  130.94238804000003
# METHOD: Sliding lp as classifier
# Execution time:  0.297823544066087
# Average MCC:  0.04824231346064252
# Average error: 47.888200000000005
# Average macro-F1: 0.364599366915705
# Average micro-F1: 0.5197999999999999
# Average Accuracy:  52.111799999999995
# Standard Deviation:  8.433560503132707
# Variance:  71.12494276
# METHOD: Incremental lp as classifier
# Execution time:  4.695599720459196
# Average MCC:  0.0995933211405458
# Average error: 45.6185
# Average macro-F1: 0.3970984487417039
# Average micro-F1: 0.5407
# Average Accuracy:  54.3815
# Standard Deviation:  11.476624187887307
# Variance:  131.71290274999998
# METHOD: lp as classifier and kde as core support extraction with cutting data method
# Execution time:  0.47761947430280394
# Average MCC:  0.7913012507119523
# Average error: 11.473299999999995
# Average macro-F1: 0.8727507560444245
# Average micro-F1: 0.8897000000000002
# Average Accuracy:  88.5267
# Standard Deviation:  13.619953675031349
# Variance:  185.50313810999995
# METHOD: lp as classifier and kde and Hellinger distance as dynamic CSE
# AMANDA-DCP Hellinger | Mean keeping percentage=0.31 | Std keeping percentage=0.19
# Execution time:  0.5963111063974971
# Average MCC:  0.8828172892588512
# Average error: 6.533200000000022
# Average macro-F1: 0.9374889289560454
# Average micro-F1: 0.9386
# Average Accuracy:  93.46679999999998
# Standard Deviation:  3.720677594202432
# Variance:  13.843441759999997
# METHOD: lp as classifier and kde and Hellinger2 distance as dynamic CSE
# AMANDA-DCP Hellinger2 | Mean keeping percentage=0.23 | Std keeping percentage=0.07
# Execution time:  0.5142288073205616
# Average MCC:  0.8949586155943456
# Average error: 5.703799999999987
# Average macro-F1: 0.9449424125406413
# Average micro-F1: 0.9455999999999999
# Average Accuracy:  94.29620000000001
# Standard Deviation:  2.878697893145441
# Variance:  8.28690156
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -10.000 | Mean keeping percentage=0.19 | Std keeping percentage=0.07
# Execution time:  0.5330209907525738
# Average MCC:  0.8953437805839515
# Average error: 5.697400000000002
# Average macro-F1: 0.9449654854160695
# Average micro-F1: 0.9457
# Average Accuracy:  94.3026
# Standard Deviation:  3.117205036567214
# Variance:  9.716967240000006
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -2.000 | Mean keeping percentage=0.21 | Std keeping percentage=0.09
# Execution time:  0.508296185113986
# Average MCC:  0.8944387477439874
# Average error: 5.829200000000014
# Average macro-F1: 0.9444643246195871
# Average micro-F1: 0.9451999999999999
# Average Accuracy:  94.17079999999999
# Standard Deviation:  3.132032145428907
# Variance:  9.809625360000002
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.500 | Mean keeping percentage=0.24 | Std keeping percentage=0.12
# Execution time:  0.5238136854942024
# Average MCC:  0.8902577154067771
# Average error: 6.019999999999996
# Average macro-F1: 0.9421969013881687
# Average micro-F1: 0.943
# Average Accuracy:  93.98
# Standard Deviation:  3.100192574663709
# Variance:  9.611193999999996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = -0.010 | Mean keeping percentage=0.48 | Std keeping percentage=0.05
# Execution time:  0.551102503582122
# Average MCC:  0.14432437693879774
# Average error: 43.23
# Average macro-F1: 0.43030943623600526
# Average micro-F1: 0.5670999999999999
# Average Accuracy:  56.77
# Standard Deviation:  15.143552159252465
# Variance:  229.327172
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.010 | Mean keeping percentage=0.10 | Std keeping percentage=0.00
# Execution time:  0.4966309237193851
# Average MCC:  0.8965524736764323
# Average error: 5.460400000000007
# Average macro-F1: 0.9457521590551239
# Average micro-F1: 0.9465
# Average Accuracy:  94.5396
# Standard Deviation:  2.9662767638910563
# Variance:  8.798797839999997
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 1.500 | Mean keeping percentage=0.15 | Std keeping percentage=0.04
# Execution time:  0.5169365089682891
# Average MCC:  0.892017753055431
# Average error: 5.861900000000006
# Average macro-F1: 0.9430929805743404
# Average micro-F1: 0.9439
# Average Accuracy:  94.1381
# Standard Deviation:  3.205903521630056
# Variance:  10.277817389999996
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 2.000 | Mean keeping percentage=0.16 | Std keeping percentage=0.06
# Execution time:  0.5254685994004227
# Average MCC:  0.8941733460128499
# Average error: 5.782900000000012
# Average macro-F1: 0.9443364595124257
# Average micro-F1: 0.9451
# Average Accuracy:  94.21709999999999
# Standard Deviation:  3.10870368320945
# Variance:  9.66403859
# METHOD: lp as classifier and kde and BBD distance as dynamic CSE
# AMANDA-DCP BBD - β = 10.000 | Mean keeping percentage=0.18 | Std keeping percentage=0.07
# Execution time:  0.5267717546845958
# Average MCC:  0.8923906798955618
# Average error: 5.7964000000000055
# Average macro-F1: 0.9434500265223715
# Average micro-F1: 0.9441999999999999
# Average Accuracy:  94.2036
# Standard Deviation:  3.02465320987382
# Variance:  9.148527040000003
# METHOD: lp as classifier and kde and HDDDM distance as dynamic CSE
# AMANDA-DCP HDDDM | Mean keeping percentage=0.44 | Std keeping percentage=0.12
# Execution time:  0.5004060308409244
# Average MCC:  0.03772067216085973
# Average error: 48.3487
# Average macro-F1: 0.3577427893296391
# Average micro-F1: 0.515
# Average Accuracy:  51.6513
# Standard Deviation:  7.526054298900587
# Variance:  56.64149331000001
# C:\Users\bruno.silva\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Pos 14 - Error reduction (Sliding SSL):-4.115653393095699
# Pos 12 - Error reduction (Incremental SSL):0.06053513797963136
# Pos 10 - Error reduction (AMANDA (Fixed)):62.88680849184707
# Pos 9 - Error reduction (AMANDA-DCP Hellinger):71.97646305516604
# Pos 3 - Error reduction (AMANDA-DCP Hellinger2):73.50253732386852
# Pos 2 - Error reduction (AMANDA-DCP BBD - β = -10.000):73.51431315618063
# Pos 6 - Error reduction (AMANDA-DCP BBD - β = -2.000):73.27180460950233
# Pos 8 - Error reduction (AMANDA-DCP BBD - β = -0.500):72.92073760869644
# Pos 11 - Error reduction (AMANDA-DCP BBD - β = -0.010):4.455312556349194
# Pos 1 - Error reduction (AMANDA-DCP BBD - β = 1.010):73.95038694648986
# Pos 7 - Error reduction (AMANDA-DCP BBD - β = 1.500):73.21163746628245
# Pos 4 - Error reduction (AMANDA-DCP BBD - β = 2.000):73.35699539638551
# Pos 5 - Error reduction (AMANDA-DCP BBD - β = 10.000):73.33215575010209
# Pos 15 - Error reduction (AMANDA-DCP HDDDM):-4.962961327430707
